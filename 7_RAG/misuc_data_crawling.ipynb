# %% [markdown]
# # 🎧 Spotify 台灣流行音樂資料抓取範例
#
# 本 notebook 範例流程：
#
# - 搜尋「2024 台灣」+ 心情類型的播放清單
#
# - 抓取每首歌的：曲名 / 藝人 / 專輯 / 發行日期 / Spotify 連結
#
# - 匯出 CSV，作為 RAG 音樂知識庫素材
#
# ---
#
# ## 1️⃣ 安裝必要套件

# %%
# !pip install requests spotipy pandas

# %% [markdown]
# ## 2️⃣ 載入套件與認證

# %%
# 匯入必要的套件
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
from requests.exceptions import ReadTimeout



# 替換為你自己的 Spotify API 憑證
client_id = 'd94fe716fad14e8ea37fa890d4d19625'
client_secret = '950e81697c954ea6b15cdc9414b7eb64'

# 初始化 Spotify 認證
sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
)

# %% [markdown]
# ## 3️⃣ 搜尋播放清單: 依照心情/情境分類

# %%
# 自訂搜尋類別組合，將心情關鍵字改為中文並增加更多可能關鍵字
mood_keywords = [
    "輕鬆", "放鬆", "悲傷", "快樂", "愛情", "能量", "懷舊",
    "學習", "運動", "開車", "專注", "派對", "睡覺",
    "咖啡", "雨天", "旅行", "夜晚", "浪漫", "回憶",
    "悠閒", "孤獨", "自由", "釋放", "幸福", "成長"
]

# 音樂類型相關關鍵字（Genres）
genre_keywords = [
    "流行", "搖滾", "嘻哈", "電子", "民謠", "古典",
    "爵士", "藍調", "R&B", "雷鬼", "舞曲", "重金屬",
    "鄉村", "靈魂", "鋼琴", "吉他", "環境音樂", "獨立音樂"
]
#time_keywords = ["2024", "2023", "最新"]
#region_keywords = ["Taiwan", "台灣", "Mandarin", "華語", "中文", "國語"]
#region_keywords = ["華語", "中文", "國語"]
# 結果儲存
all_results = []

# %% [markdown]
# ## 4️⃣ 輸入播放清單 ID 抓取歌曲詳細資料

# %%
# 開始迴圈搜尋：中文情緒或音樂類型分類的播放清單
for mood in mood_keywords:
    for genre in genre_keywords:
        query = f"{mood} {genre}"  # 結合情緒與音樂類型
        try:
            search_result = sp.search(q=query, type='playlist', limit=5)
            for playlist in search_result['playlists']['items']:
                all_results.append({
                    '搜尋關鍵字': query,
                    '播放清單名稱': playlist['name'],
                    '播放清單ID': playlist['id'],
                    '播放清單連結': playlist['external_urls']['spotify']
                })
            print(f"✅ 已完成: {query}")
        except Exception as e:
            print(f"❌ 查詢失敗: {query}，錯誤：{e}")
        time.sleep(0.5)  # 避免API超量

# 匯出結果
df = pd.DataFrame(all_results)
df.to_csv("Chinese_Mood_Genre_Playlist.csv", index=False, encoding="utf-8-sig")
print("🎉 已匯出 Chinese_Mood_Genre_Playlist.csv")
# Out:
# ❌ 查詢失敗: 輕鬆 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 輕鬆 搖滾
# ✅ 已完成: 輕鬆 嘻哈
# ✅ 已完成: 輕鬆 電子
# ✅ 已完成: 輕鬆 民謠
# ❌ 查詢失敗: 輕鬆 古典，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 輕鬆 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 輕鬆 藍調
# ❌ 查詢失敗: 輕鬆 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 輕鬆 雷鬼
# ✅ 已完成: 輕鬆 舞曲
# ❌ 查詢失敗: 輕鬆 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 輕鬆 鄉村
# ✅ 已完成: 輕鬆 靈魂
# ✅ 已完成: 輕鬆 鋼琴
# ✅ 已完成: 輕鬆 吉他
# ❌ 查詢失敗: 輕鬆 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 輕鬆 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 放鬆 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 放鬆 搖滾
# ✅ 已完成: 放鬆 嘻哈
# ✅ 已完成: 放鬆 電子
# ✅ 已完成: 放鬆 民謠
# ❌ 查詢失敗: 放鬆 古典，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 放鬆 爵士
# ✅ 已完成: 放鬆 藍調
# ❌ 查詢失敗: 放鬆 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 放鬆 雷鬼
# ✅ 已完成: 放鬆 舞曲
# ❌ 查詢失敗: 放鬆 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 放鬆 鄉村
# ✅ 已完成: 放鬆 靈魂
# ✅ 已完成: 放鬆 鋼琴
# ✅ 已完成: 放鬆 吉他
# ❌ 查詢失敗: 放鬆 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 放鬆 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 悲傷 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 搖滾
# ✅ 已完成: 悲傷 嘻哈
# ❌ 查詢失敗: 悲傷 電子，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 民謠
# ✅ 已完成: 悲傷 古典
# ✅ 已完成: 悲傷 爵士
# ❌ 查詢失敗: 悲傷 藍調，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 悲傷 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 雷鬼
# ✅ 已完成: 悲傷 舞曲
# ❌ 查詢失敗: 悲傷 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 鄉村
# ✅ 已完成: 悲傷 靈魂
# ❌ 查詢失敗: 悲傷 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 吉他
# ❌ 查詢失敗: 悲傷 環境音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悲傷 獨立音樂
# ❌ 查詢失敗: 快樂 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 快樂 搖滾
# ✅ 已完成: 快樂 嘻哈
# ✅ 已完成: 快樂 電子
# ❌ 查詢失敗: 快樂 民謠，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 快樂 古典
# ✅ 已完成: 快樂 爵士
# ✅ 已完成: 快樂 藍調
# ❌ 查詢失敗: 快樂 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 快樂 雷鬼
# ✅ 已完成: 快樂 舞曲
# ❌ 查詢失敗: 快樂 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 快樂 鄉村
# ✅ 已完成: 快樂 靈魂
# ❌ 查詢失敗: 快樂 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 快樂 吉他
# ❌ 查詢失敗: 快樂 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 快樂 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 流行
# ✅ 已完成: 愛情 搖滾
# ❌ 查詢失敗: 愛情 嘻哈，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 電子
# ✅ 已完成: 愛情 民謠
# ✅ 已完成: 愛情 古典
# ❌ 查詢失敗: 愛情 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 藍調
# ❌ 查詢失敗: 愛情 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 雷鬼
# ✅ 已完成: 愛情 舞曲
# ❌ 查詢失敗: 愛情 重金屬，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 愛情 鄉村，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 靈魂
# ❌ 查詢失敗: 愛情 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 愛情 吉他
# ❌ 查詢失敗: 愛情 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 愛情 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 能量 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 能量 搖滾
# ✅ 已完成: 能量 嘻哈
# ✅ 已完成: 能量 電子
# ✅ 已完成: 能量 民謠
# ✅ 已完成: 能量 古典
# ✅ 已完成: 能量 爵士
# ✅ 已完成: 能量 藍調
# ❌ 查詢失敗: 能量 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 能量 雷鬼
# ✅ 已完成: 能量 舞曲
# ❌ 查詢失敗: 能量 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 能量 鄉村
# ✅ 已完成: 能量 靈魂
# ❌ 查詢失敗: 能量 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 能量 吉他
# ❌ 查詢失敗: 能量 環境音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 能量 獨立音樂
# ✅ 已完成: 懷舊 流行
# ✅ 已完成: 懷舊 搖滾
# ✅ 已完成: 懷舊 嘻哈
# ✅ 已完成: 懷舊 電子
# ✅ 已完成: 懷舊 民謠
# ✅ 已完成: 懷舊 古典
# ✅ 已完成: 懷舊 爵士
# ✅ 已完成: 懷舊 藍調
# ✅ 已完成: 懷舊 R&B
# ✅ 已完成: 懷舊 雷鬼
# ✅ 已完成: 懷舊 舞曲
# ✅ 已完成: 懷舊 重金屬
# ✅ 已完成: 懷舊 鄉村
# ✅ 已完成: 懷舊 靈魂
# ✅ 已完成: 懷舊 鋼琴
# ✅ 已完成: 懷舊 吉他
# ✅ 已完成: 懷舊 環境音樂
# ❌ 查詢失敗: 懷舊 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 學習 流行
# ✅ 已完成: 學習 搖滾
# ✅ 已完成: 學習 嘻哈
# ✅ 已完成: 學習 電子
# ✅ 已完成: 學習 民謠
# ✅ 已完成: 學習 古典
# ❌ 查詢失敗: 學習 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 學習 藍調
# ✅ 已完成: 學習 R&B
# ✅ 已完成: 學習 雷鬼
# ✅ 已完成: 學習 舞曲
# ❌ 查詢失敗: 學習 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 學習 鄉村
# ✅ 已完成: 學習 靈魂
# ✅ 已完成: 學習 鋼琴
# ✅ 已完成: 學習 吉他
# ❌ 查詢失敗: 學習 環境音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 學習 獨立音樂
# ✅ 已完成: 運動 流行
# ✅ 已完成: 運動 搖滾
# ✅ 已完成: 運動 嘻哈
# ✅ 已完成: 運動 電子
# ✅ 已完成: 運動 民謠
# ✅ 已完成: 運動 古典
# ✅ 已完成: 運動 爵士
# ✅ 已完成: 運動 藍調
# ❌ 查詢失敗: 運動 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 運動 雷鬼
# ✅ 已完成: 運動 舞曲
# ✅ 已完成: 運動 重金屬
# ✅ 已完成: 運動 鄉村
# ✅ 已完成: 運動 靈魂
# ✅ 已完成: 運動 鋼琴
# ✅ 已完成: 運動 吉他
# ✅ 已完成: 運動 環境音樂
# ❌ 查詢失敗: 運動 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 開車 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 開車 搖滾
# ✅ 已完成: 開車 嘻哈
# ✅ 已完成: 開車 電子
# ✅ 已完成: 開車 民謠
# ✅ 已完成: 開車 古典
# ✅ 已完成: 開車 爵士
# ✅ 已完成: 開車 藍調
# ❌ 查詢失敗: 開車 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 開車 雷鬼
# ✅ 已完成: 開車 舞曲
# ✅ 已完成: 開車 重金屬
# ✅ 已完成: 開車 鄉村
# ✅ 已完成: 開車 靈魂
# ✅ 已完成: 開車 鋼琴
# ✅ 已完成: 開車 吉他
# ❌ 查詢失敗: 開車 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 開車 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 專注 流行
# ✅ 已完成: 專注 搖滾
# ✅ 已完成: 專注 嘻哈
# ✅ 已完成: 專注 電子
# ✅ 已完成: 專注 民謠
# ✅ 已完成: 專注 古典
# ✅ 已完成: 專注 爵士
# ✅ 已完成: 專注 藍調
# ❌ 查詢失敗: 專注 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 專注 雷鬼
# ✅ 已完成: 專注 舞曲
# ❌ 查詢失敗: 專注 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 專注 鄉村
# ✅ 已完成: 專注 靈魂
# ✅ 已完成: 專注 鋼琴
# ✅ 已完成: 專注 吉他
# ❌ 查詢失敗: 專注 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 專注 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 派對 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 派對 搖滾
# ✅ 已完成: 派對 嘻哈
# ✅ 已完成: 派對 電子
# ✅ 已完成: 派對 民謠
# ✅ 已完成: 派對 古典
# ❌ 查詢失敗: 派對 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 派對 藍調
# ❌ 查詢失敗: 派對 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 派對 雷鬼
# ✅ 已完成: 派對 舞曲
# ❌ 查詢失敗: 派對 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 派對 鄉村
# ❌ 查詢失敗: 派對 靈魂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 派對 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 派對 吉他
# ❌ 查詢失敗: 派對 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 派對 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 睡覺 流行
# ✅ 已完成: 睡覺 搖滾
# ✅ 已完成: 睡覺 嘻哈
# ✅ 已完成: 睡覺 電子
# ✅ 已完成: 睡覺 民謠
# ✅ 已完成: 睡覺 古典
# ❌ 查詢失敗: 睡覺 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 睡覺 藍調
# ✅ 已完成: 睡覺 R&B
# ✅ 已完成: 睡覺 雷鬼
# ✅ 已完成: 睡覺 舞曲
# ❌ 查詢失敗: 睡覺 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 睡覺 鄉村
# ✅ 已完成: 睡覺 靈魂
# ❌ 查詢失敗: 睡覺 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 睡覺 吉他
# ❌ 查詢失敗: 睡覺 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 睡覺 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 咖啡 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 咖啡 搖滾
# ✅ 已完成: 咖啡 嘻哈
# ✅ 已完成: 咖啡 電子
# ✅ 已完成: 咖啡 民謠
# ✅ 已完成: 咖啡 古典
# ✅ 已完成: 咖啡 爵士
# ✅ 已完成: 咖啡 藍調
# ❌ 查詢失敗: 咖啡 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 咖啡 雷鬼
# ❌ 查詢失敗: 咖啡 舞曲，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 咖啡 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 咖啡 鄉村
# ✅ 已完成: 咖啡 靈魂
# ✅ 已完成: 咖啡 鋼琴
# ✅ 已完成: 咖啡 吉他
# ❌ 查詢失敗: 咖啡 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 咖啡 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 雨天 流行
# ✅ 已完成: 雨天 搖滾
# ✅ 已完成: 雨天 嘻哈
# ✅ 已完成: 雨天 電子
# ✅ 已完成: 雨天 民謠
# ✅ 已完成: 雨天 古典
# ✅ 已完成: 雨天 爵士
# ✅ 已完成: 雨天 藍調
# ❌ 查詢失敗: 雨天 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 雨天 雷鬼
# ✅ 已完成: 雨天 舞曲
# ❌ 查詢失敗: 雨天 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 雨天 鄉村
# ✅ 已完成: 雨天 靈魂
# ❌ 查詢失敗: 雨天 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 雨天 吉他
# ❌ 查詢失敗: 雨天 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 雨天 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 旅行 流行
# ✅ 已完成: 旅行 搖滾
# ✅ 已完成: 旅行 嘻哈
# ❌ 查詢失敗: 旅行 電子，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 旅行 民謠
# ✅ 已完成: 旅行 古典
# ❌ 查詢失敗: 旅行 爵士，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 旅行 藍調
# ❌ 查詢失敗: 旅行 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 旅行 雷鬼
# ✅ 已完成: 旅行 舞曲
# ❌ 查詢失敗: 旅行 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 旅行 鄉村
# ✅ 已完成: 旅行 靈魂
# ✅ 已完成: 旅行 鋼琴
# ✅ 已完成: 旅行 吉他
# ❌ 查詢失敗: 旅行 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 旅行 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 夜晚 流行
# ✅ 已完成: 夜晚 搖滾
# ✅ 已完成: 夜晚 嘻哈
# ✅ 已完成: 夜晚 電子
# ✅ 已完成: 夜晚 民謠
# ✅ 已完成: 夜晚 古典
# ✅ 已完成: 夜晚 爵士
# ✅ 已完成: 夜晚 藍調
# ✅ 已完成: 夜晚 R&B
# ✅ 已完成: 夜晚 雷鬼
# ✅ 已完成: 夜晚 舞曲
# ✅ 已完成: 夜晚 重金屬
# ✅ 已完成: 夜晚 鄉村
# ✅ 已完成: 夜晚 靈魂
# ❌ 查詢失敗: 夜晚 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 夜晚 吉他
# ✅ 已完成: 夜晚 環境音樂
# ❌ 查詢失敗: 夜晚 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 浪漫 流行，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 浪漫 搖滾，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 浪漫 嘻哈
# ✅ 已完成: 浪漫 電子
# ✅ 已完成: 浪漫 民謠
# ✅ 已完成: 浪漫 古典
# ✅ 已完成: 浪漫 爵士
# ✅ 已完成: 浪漫 藍調
# ❌ 查詢失敗: 浪漫 R&B，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 浪漫 雷鬼，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 浪漫 舞曲
# ❌ 查詢失敗: 浪漫 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 浪漫 鄉村
# ✅ 已完成: 浪漫 靈魂
# ✅ 已完成: 浪漫 鋼琴
# ✅ 已完成: 浪漫 吉他
# ❌ 查詢失敗: 浪漫 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 浪漫 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 回憶 流行，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 回憶 搖滾
# ✅ 已完成: 回憶 嘻哈
# ✅ 已完成: 回憶 電子
# ✅ 已完成: 回憶 民謠
# ✅ 已完成: 回憶 古典
# ✅ 已完成: 回憶 爵士
# ✅ 已完成: 回憶 藍調
# ❌ 查詢失敗: 回憶 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 回憶 雷鬼
# ❌ 查詢失敗: 回憶 舞曲，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 回憶 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 回憶 鄉村
# ✅ 已完成: 回憶 靈魂
# ✅ 已完成: 回憶 鋼琴
# ✅ 已完成: 回憶 吉他
# ❌ 查詢失敗: 回憶 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 回憶 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悠閒 流行
# ✅ 已完成: 悠閒 搖滾
# ✅ 已完成: 悠閒 嘻哈
# ✅ 已完成: 悠閒 電子
# ✅ 已完成: 悠閒 民謠
# ✅ 已完成: 悠閒 古典
# ✅ 已完成: 悠閒 爵士
# ✅ 已完成: 悠閒 藍調
# ❌ 查詢失敗: 悠閒 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悠閒 雷鬼
# ✅ 已完成: 悠閒 舞曲
# ❌ 查詢失敗: 悠閒 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 悠閒 鄉村
# ✅ 已完成: 悠閒 靈魂
# ✅ 已完成: 悠閒 鋼琴
# ✅ 已完成: 悠閒 吉他
# ❌ 查詢失敗: 悠閒 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 悠閒 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 孤獨 流行
# ✅ 已完成: 孤獨 搖滾
# ✅ 已完成: 孤獨 嘻哈
# ✅ 已完成: 孤獨 電子
# ✅ 已完成: 孤獨 民謠
# ✅ 已完成: 孤獨 古典
# ✅ 已完成: 孤獨 爵士
# ✅ 已完成: 孤獨 藍調
# ❌ 查詢失敗: 孤獨 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 孤獨 雷鬼
# ✅ 已完成: 孤獨 舞曲
# ❌ 查詢失敗: 孤獨 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 孤獨 鄉村
# ❌ 查詢失敗: 孤獨 靈魂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 孤獨 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 孤獨 吉他
# ❌ 查詢失敗: 孤獨 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 孤獨 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 自由 流行
# ✅ 已完成: 自由 搖滾
# ✅ 已完成: 自由 嘻哈
# ❌ 查詢失敗: 自由 電子，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 自由 民謠
# ✅ 已完成: 自由 古典
# ✅ 已完成: 自由 爵士
# ❌ 查詢失敗: 自由 藍調，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 自由 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 自由 雷鬼
# ✅ 已完成: 自由 舞曲
# ❌ 查詢失敗: 自由 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 自由 鄉村
# ❌ 查詢失敗: 自由 靈魂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 自由 鋼琴，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 自由 吉他
# ❌ 查詢失敗: 自由 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 自由 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 釋放 流行
# ✅ 已完成: 釋放 搖滾
# ✅ 已完成: 釋放 嘻哈
# ✅ 已完成: 釋放 電子
# ✅ 已完成: 釋放 民謠
# ✅ 已完成: 釋放 古典
# ✅ 已完成: 釋放 爵士
# ✅ 已完成: 釋放 藍調
# ❌ 查詢失敗: 釋放 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 釋放 雷鬼
# ✅ 已完成: 釋放 舞曲
# ❌ 查詢失敗: 釋放 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 釋放 鄉村
# ✅ 已完成: 釋放 靈魂
# ✅ 已完成: 釋放 鋼琴
# ✅ 已完成: 釋放 吉他
# ❌ 查詢失敗: 釋放 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 釋放 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 幸福 流行
# ✅ 已完成: 幸福 搖滾
# ❌ 查詢失敗: 幸福 嘻哈，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 幸福 電子
# ✅ 已完成: 幸福 民謠
# ✅ 已完成: 幸福 古典
# ✅ 已完成: 幸福 爵士
# ❌ 查詢失敗: 幸福 藍調，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 幸福 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 幸福 雷鬼
# ❌ 查詢失敗: 幸福 舞曲，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 幸福 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 幸福 鄉村
# ✅ 已完成: 幸福 靈魂
# ✅ 已完成: 幸福 鋼琴
# ✅ 已完成: 幸福 吉他
# ❌ 查詢失敗: 幸福 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 幸福 獨立音樂，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 成長 流行
# ✅ 已完成: 成長 搖滾
# ✅ 已完成: 成長 嘻哈
# ✅ 已完成: 成長 電子
# ✅ 已完成: 成長 民謠
# ✅ 已完成: 成長 古典
# ✅ 已完成: 成長 爵士
# ✅ 已完成: 成長 藍調
# ❌ 查詢失敗: 成長 R&B，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 成長 雷鬼
# ✅ 已完成: 成長 舞曲
# ❌ 查詢失敗: 成長 重金屬，錯誤：'NoneType' object is not subscriptable
# ✅ 已完成: 成長 鄉村
# ✅ 已完成: 成長 靈魂
# ✅ 已完成: 成長 鋼琴
# ✅ 已完成: 成長 吉他
# ❌ 查詢失敗: 成長 環境音樂，錯誤：'NoneType' object is not subscriptable
# ❌ 查詢失敗: 成長 獨立音樂，錯誤：'NoneType' object is not subscriptable
# 🎉 已匯出 Chinese_Mood_Genre_Playlist.csv

# %% [markdown]
# ## 完成抓取播放清單
#
# 這樣你就可以把「播放清單」整理成結構化表格，直接送入自己的RAG流程了。

# %% [markdown]
# ## 5️⃣ 抓取歌曲詳細資料

# %%
# 建立 Spotify 連線
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
))


# 假設這裡是你從搜尋程式抓下來的播放清單資訊
playlist_info_list = [
    {"name": item['播放清單名稱'], "keyword": item['搜尋關鍵字'], "id": item['播放清單ID']}
    for item in all_results
]

# 結果儲存
all_tracks = []

# %%
# 逐一抓取每個播放清單的內容
for playlist in playlist_info_list:
    playlist_name = playlist['name']
    keyword = playlist['keyword']
    playlist_id = playlist['id']

    print(f"\n🎵 正在抓取: {playlist_name}(關鍵字: {keyword})")

    offset = 0
    limit = 100

    while True:
        try:
            # 每次請求最多100首歌
            results = sp.playlist_items(playlist_id, offset=offset, limit=limit, additional_types=['track'])
            items = results['items']

            if not items:
                break

            for item in items:
                track = item['track']
                if track is None:
                    continue

                all_tracks.append({
                    "播放清單名稱": playlist_name,
                    "搜尋關鍵字": keyword,
                    "歌曲名稱": track['name'],
                    "藝人": ", ".join([artist['name'] for artist in track['artists']]),
                    "專輯": track['album']['name'],
                    "發行日": track['album']['release_date']
                })

            offset += limit
            time.sleep(0.2)  # 避免太快請求，防止API封鎖

        except ReadTimeout:
            print(f"⚠️ 讀取超時!等待5秒後重試...(offset={offset})")
            time.sleep(5)  # 超時等待，然後重試
            continue

        except Exception as e:
            print(f"❌ 抓取失敗，錯誤: {e}")
            break

# 結果轉成 DataFrame
df = pd.DataFrame(all_tracks)

# 儲存為 CSV
df.to_csv("Taiwan_Playlist_Songs.csv", index=False, encoding='utf-8-sig')

print(f"\n✅ 已完成,總共抓取 {len(df)} 首歌,結果已儲存:Taiwan_Playlist_Songs.csv")
# Out:
# 🎵 正在抓取: 輕鬆搖滾(關鍵字: 輕鬆 搖滾)
#
# 🎵 正在抓取: 輕鬆+台式搖滾(關鍵字: 輕鬆 搖滾)
#
# 🎵 正在抓取: chinese rnb ☁️(關鍵字: 輕鬆 嘻哈)
#
# 🎵 正在抓取: 輕鬆又嘻哈的高級氛圍🖤(關鍵字: 輕鬆 嘻哈)
#
# 🎵 正在抓取: Chinese Soft Rap 華語輕饒舌(關鍵字: 輕鬆 嘻哈)
#
# 🎵 正在抓取: 輕鬆的狀態(關鍵字: 輕鬆 嘻哈)
#
# 🎵 正在抓取: 專注工作(輕電子)(關鍵字: 輕鬆 電子)
#
# 🎵 正在抓取: 輕鬆電子(關鍵字: 輕鬆 電子)
#
# 🎵 正在抓取: 港式MK歌 & Remix(關鍵字: 輕鬆 電子)
#
# 🎵 正在抓取: 綠鋼琴／綠森林／古典鋼琴／現代鋼琴／助眠樂曲(關鍵字: 輕鬆 古典)
#
# 🎵 正在抓取: 放輕鬆，聽古典 Classical Chill(關鍵字: 輕鬆 古典)
#
# 🎵 正在抓取: 寶寶睡眠鋼琴 輕柔旋律入夢鄉 Babe Sleep Piano Lullaby with Soothing Melody(關鍵字: 輕鬆 古典)
#
# 🎵 正在抓取: 貴族音樂古典 – 睡眠導入舒心大提琴: 鋼琴放鬆輕聽(關鍵字: 輕鬆 古典)
#
# 🎵 正在抓取: 國語兒歌(關鍵字: 輕鬆 藍調)
#
# 🎵 正在抓取: #4 Ocean Breeze｜Music for better sleep(關鍵字: 輕鬆 藍調)
#
# 🎵 正在抓取: Bossa Nova｜慵懒风情(關鍵字: 輕鬆 舞曲)
#
# 🎵 正在抓取: 輕鬆不插電(關鍵字: 輕鬆 舞曲)
#
# 🎵 正在抓取: 陳老師的輕鬆舞曲(關鍵字: 輕鬆 舞曲)
#
# 🎵 正在抓取: 港式MK歌 & Remix(關鍵字: 輕鬆 舞曲)
#
# 🎵 正在抓取: #1 Floating Slumber ｜Music for better sleep(關鍵字: 輕鬆 靈魂)
#
# 🎵 正在抓取: 秋日早晨的輕鬆爵士與靈魂(關鍵字: 輕鬆 靈魂)
#
# 🎵 正在抓取: 華語流行 鋼琴純音樂 C-POP Piano Cover(關鍵字: 輕鬆 鋼琴)
#
# 🎵 正在抓取: 鋼琴輕音樂：迪士尼動畫精選 Disney Piano Music for Relaxtion(關鍵字: 輕鬆 鋼琴)
#
# 🎵 正在抓取: 輕音樂 睡眠音樂  鋼琴音樂 Piano Sleep Music(關鍵字: 輕鬆 鋼琴)
#
# 🎵 正在抓取: 咖啡廳音樂 Relaxing Coffee Music BGM(關鍵字: 輕鬆 鋼琴)
#
# 🎵 正在抓取: 睡眠 放鬆催眠旋律 療癒 純音樂 鋼琴曲 Sleepy Melody Before Bedtime(關鍵字: 輕鬆 鋼琴)
#
# 🎵 正在抓取: 寶寶睡眠鋼琴 輕柔旋律入夢鄉 Babe Sleep Piano Lullaby with Soothing Melody(關鍵字: 輕鬆 環境音樂)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 輕鬆 環境音樂)
#
# 🎵 正在抓取: 寶寶睡眠鋼琴 輕柔旋律入夢鄉 Babe Sleep Piano Lullaby with Soothing Melody(關鍵字: 輕鬆 環境音樂)
#
# 🎵 正在抓取: Taiwan Indie Radio 台灣硬地電台 Chill R&B Laid-back groovy 好聽 獨立 地下 樂團 臥室 音樂 窮苦 哀傷 文青 輕音樂 輕鬆開車 金曲 金音精選 (關鍵字: 輕鬆 獨立音樂)
#
# 🎵 正在抓取: 孤獨搖滾！ OP ED OST(關鍵字: 放鬆 搖滾)
#
# 🎵 正在抓取: HappyRuff 狗-放鬆軟搖(關鍵字: 放鬆 搖滾)
#
# 🎵 正在抓取: 好像有點油又不太油(關鍵字: 放鬆 搖滾)
#
# 🎵 正在抓取: KTV必點歌單 獨立/搖滾/抒情(關鍵字: 放鬆 搖滾)
#
# 🎵 正在抓取: ⛺️凹豆咖快看！ 露營放鬆的⚡️鄉村搖滾樂 (2)(關鍵字: 放鬆 搖滾)
#
# 🎵 正在抓取: 大嘻哈時代2(關鍵字: 放鬆 嘻哈)
#
# 🎵 正在抓取: chinese rnb ☁️(關鍵字: 放鬆 嘻哈)
#
# 🎵 正在抓取: HIP-HOP 瘋嘻哈(關鍵字: 放鬆 嘻哈)
#
# 🎵 正在抓取: K-HIPHOP (korean rap)(關鍵字: 放鬆 嘻哈)
#
# 🎵 正在抓取: 中文融合音樂 (Chinese - Fussion) ,爵士,嘻哈,放客,饒舌,迪斯可,獨立音樂,9m88,吳卓源,異鄉人,J-Sheon(關鍵字: 放鬆 嘻哈)
#
# 🎵 正在抓取: 心震えるエレクトロニカ(關鍵字: 放鬆 電子)
#
# 🎵 正在抓取: 電子放鬆 夏日(關鍵字: 放鬆 電子)
#
# 🎵 正在抓取: 慢搖 Downtempo(關鍵字: 放鬆 電子)
#
# 🎵 正在抓取:  (電子放鬆)Indie Electro Relax (關鍵字: 放鬆 電子)
#
# 🎵 正在抓取: DEEP HOUSE COMERCIAL(關鍵字: 放鬆 電子)
#
# 🎵 正在抓取: 柔美豎琴音 恬適睡眠 Healing Harp Melody to Sleep(關鍵字: 放鬆 民謠)
#
# 🎵 正在抓取: 渡假放鬆輕爵士 Jazz & Bossa Vacation Music(關鍵字: 放鬆 爵士)
#
# 🎵 正在抓取: Bossa Nova｜慵懒风情(關鍵字: 放鬆 爵士)
#
# 🎵 正在抓取: 咖啡廳音樂 Relaxing Coffee Music BGM(關鍵字: 放鬆 爵士)
#
# 🎵 正在抓取: c'est la vie 香榭咖啡館(關鍵字: 放鬆 爵士)
#
# 🎵 正在抓取: 咖啡館音樂–放鬆鋼琴爵士樂 (2)(關鍵字: 放鬆 爵士)
#
# 🎵 正在抓取: 孫燕姿AUT NIHILO 就在日落以後巡迴演唱會 STEFANIE SUN YANZI 孙燕姿就在日落以后(關鍵字: 放鬆 藍調)
#
# 🎵 正在抓取: 周杰倫鋼琴曲純音樂 Jay Chou Piano Instrumental Collection(關鍵字: 放鬆 藍調)
#
# 🎵 正在抓取: 鋼琴.靜心Piano Peace(關鍵字: 放鬆 藍調)
#
# 🎵 正在抓取: 艾奧迪 Ludovico Einaudi 名曲精選(關鍵字: 放鬆 藍調)
#
# 🎵 正在抓取: 周傳雄＋王傑＋張信哲＋林隆璇＋薛岳＋李壽全＋鍾鎮濤(關鍵字: 放鬆 藍調)
#
# 🎵 正在抓取: HappyRuff 狗-放鬆雷鬼(關鍵字: 放鬆 雷鬼)
#
# 🎵 正在抓取: Happy Ruff 狗-放鬆雷鬼 vol.2(關鍵字: 放鬆 雷鬼)
#
# 🎵 正在抓取: 雷鬼或放鬆(關鍵字: 放鬆 雷鬼)
#
# 🎵 正在抓取: 最好聽粵語廣東歌曲 Best Cantonese Songs(關鍵字: 放鬆 舞曲)
#
# 🎵 正在抓取: Bossa Nova｜慵懒风情(關鍵字: 放鬆 舞曲)
#
# 🎵 正在抓取: 輕鬆不插電(關鍵字: 放鬆 舞曲)
#
# 🎵 正在抓取: 開店 迪斯可 放可 舞曲(關鍵字: 放鬆 舞曲)
#
# 🎵 正在抓取: 社交舞曲(關鍵字: 放鬆 舞曲)
#
# 🎵 正在抓取: ⛺️凹豆咖快看！ 露營放鬆的⚡️鄉村搖滾樂 (2)(關鍵字: 放鬆 鄉村)
#
# 🎵 正在抓取: 鄉村世間情 Country Sounds(關鍵字: 放鬆 鄉村)
#
# 🎵 正在抓取: 靈魂巨人泰迪 Teddy Swims | 必聽精選 Hot Hits(關鍵字: 放鬆 靈魂)
#
# 🎵 正在抓取: 鋼琴.靜心Piano Peace(關鍵字: 放鬆 靈魂)
#
# 🎵 正在抓取: 慵懶放鬆靈魂樂(關鍵字: 放鬆 靈魂)
#
# 🎵 正在抓取: #1 Floating Slumber ｜Music for better sleep(關鍵字: 放鬆 靈魂)
#
# 🎵 正在抓取: 婚禮音樂 - 中文(關鍵字: 放鬆 靈魂)
#
# 🎵 正在抓取: 睡眠音樂 深度睡眠 鋼琴音樂 白噪音 讓人放鬆 舒眠 紓壓 純音樂 Soothing Melody for Deep Sleep(關鍵字: 放鬆 鋼琴)
#
# 🎵 正在抓取: 咖啡廳音樂 Relaxing Coffee Music BGM(關鍵字: 放鬆 鋼琴)
#
# 🎵 正在抓取: 鋼琴.靜心Piano Peace(關鍵字: 放鬆 鋼琴)
#
# 🎵 正在抓取: 睡眠 放鬆催眠旋律 療癒 純音樂 鋼琴曲 Sleepy Melody Before Bedtime(關鍵字: 放鬆 鋼琴)
#
# 🎵 正在抓取: 1990-2022日本動漫歌曲合輯(關鍵字: 放鬆 鋼琴)
#
# 🎵 正在抓取: 2024-2025 影視歌曲 | 陸劇 電影 OST(關鍵字: 放鬆 吉他)
#
# 🎵 正在抓取: 動畫歌曲*咒迴，鬼滅，火影，迪士尼，吉卜力，巨人，獵人，伍六七，天官，肌肉魔法使，我推の子，怪獸8號，hazbin...*(關鍵字: 放鬆 吉他)
#
# 🎵 正在抓取: 轻柔吉他(關鍵字: 放鬆 吉他)
#
# 🎵 正在抓取: (原曲) 乐队的夏天 第一季 | The Big Band 1 | 樂隊的夏天 第一季(關鍵字: 放鬆 吉他)
#
# 🎵 正在抓取: スタジオ ジブリ STUDIO GHIBLI(關鍵字: 放鬆 吉他)
#
# 🎵 正在抓取: 寶寶潛能開發音樂 胎教古典音樂  Baby Brain Development Music ＆  Pregnancy Music(關鍵字: 放鬆 環境音樂)
#
# 🎵 正在抓取: 任然好聽歌(關鍵字: 悲傷 流行)
#
# 🎵 正在抓取: 伤心情歌(關鍵字: 悲傷 流行)
#
# 🎵 正在抓取: 悲傷時刻到來(關鍵字: 悲傷 流行)
#
# 🎵 正在抓取: 悲傷搖滾(關鍵字: 悲傷 搖滾)
#
# 🎵 正在抓取: 原子邦妮電子迷幻悲傷歌單(關鍵字: 悲傷 電子)
#
# 🎵 正在抓取: 麻油葉的宇宙(關鍵字: 悲傷 民謠)
#
# 🎵 正在抓取: Styling #2(神聖、憂傷、古典)(關鍵字: 悲傷 古典)
#
# 🎵 正在抓取: [1小時串燒] 鐵肺歌姬歌后-A-Lin/戴愛玲/鄧紫棋/陳芳語/彭佳慧/艾怡良/張若凡｜摯友、空港、愛你、有一種悲傷、相見恨晚、走在紅毯那一天、FlyAway(關鍵字: 悲傷 藍調)
#
# 🎵 正在抓取: 六年級愛情歌(關鍵字: 悲傷 藍調)
#
# 🎵 正在抓取: iX1-TWC 夢幻女聲(關鍵字: 悲傷 藍調)
#
# 🎵 正在抓取: 《我的完美秘書》韓劇原聲帶(關鍵字: 悲傷 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 悲傷 R&B)
#
# 🎵 正在抓取: 任然好聽歌(關鍵字: 悲傷 R&B)
#
# 🎵 正在抓取: 😕 秒哭emo歌单(關鍵字: 悲傷 重金屬)
#
# 🎵 正在抓取: 深夜EMO歌單😭(關鍵字: 悲傷 重金屬)
#
# 🎵 正在抓取: 林夕：哥哥字傳(關鍵字: 悲傷 靈魂)
#
# 🎵 正在抓取: 😕 秒哭emo歌单(關鍵字: 悲傷 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 悲傷 獨立音樂)
#
# 🎵 正在抓取: 深夜EMO歌單😭(關鍵字: 悲傷 獨立音樂)
#
# 🎵 正在抓取: 失戀必聽秒哭歌單(關鍵字: 悲傷 獨立音樂)
#
# 🎵 正在抓取: 日文抒情歌單(關鍵字: 悲傷 獨立音樂)
#
# 🎵 正在抓取: 2025流行英文歌單(關鍵字: 快樂 流行)
#
# 🎵 正在抓取: 最好聽粵語廣東歌曲 Best Cantonese Songs(關鍵字: 快樂 流行)
#
# 🎵 正在抓取: 流行台語(不定時更新)(關鍵字: 快樂 流行)
#
# 🎵 正在抓取: 搖滾生日快樂歌(關鍵字: 快樂 搖滾)
#
# 🎵 正在抓取: 台灣獨立樂團(關鍵字: 快樂 搖滾)
#
# 🎵 正在抓取: Taiwanese Bands(關鍵字: 快樂 搖滾)
#
# 🎵 正在抓取: ㄆㄎ(關鍵字: 快樂 搖滾)
#
# 🎵 正在抓取: 不搖滾會死(關鍵字: 快樂 搖滾)
#
# 🎵 正在抓取: 炸音響快歌(關鍵字: 快樂 嘻哈)
#
# 🎵 正在抓取: 高端渣男開車把妹歌單(關鍵字: 快樂 嘻哈)
#
# 🎵 正在抓取: 上課high歌(關鍵字: 快樂 嘻哈)
#
# 🎵 正在抓取: 我的快樂嘻哈(關鍵字: 快樂 嘻哈)
#
# 🎵 正在抓取: 輕快節奏 - 電子音樂(關鍵字: 快樂 電子)
#
# 🎵 正在抓取: Psychedelic 快節奏大麻迷幻電子音樂 專注工作 (關鍵字: 快樂 電子)
#
# 🎵 正在抓取: 緩拍 電子音樂 電音 動感音樂(關鍵字: 快樂 電子)
#
# 🎵 正在抓取: Contemporary classical music(關鍵字: 快樂 電子)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 快樂 電子)
#
# 🎵 正在抓取: Rock-迷幻搖滾 Psychedelic rock(關鍵字: 快樂 民謠)
#
# 🎵 正在抓取: 民謠-搖滾-快樂(關鍵字: 快樂 民謠)
#
# 🎵 正在抓取: 上班舒心輕音樂古典 Easy Listening Classical Music for Office Working(關鍵字: 快樂 古典)
#
# 🎵 正在抓取: 寶寶睡眠鋼琴 輕柔旋律入夢鄉 Babe Sleep Piano Lullaby with Soothing Melody(關鍵字: 快樂 古典)
#
# 🎵 正在抓取: 輕快古典音樂(關鍵字: 快樂 古典)
#
# 🎵 正在抓取: DG古典．百年經典(關鍵字: 快樂 古典)
#
# 🎵 正在抓取: 我是遺物整理師:韓可魯的音樂播放清單(關鍵字: 快樂 古典)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 快樂 爵士)
#
# 🎵 正在抓取: Bossa Nova｜慵懒风情(關鍵字: 快樂 爵士)
#
# 🎵 正在抓取: 渡假放鬆輕爵士 Jazz & Bossa Vacation Music(關鍵字: 快樂 爵士)
#
# 🎵 正在抓取: c'est la vie 香榭咖啡館(關鍵字: 快樂 爵士)
#
# 🎵 正在抓取: 爵士。早午餐。咖啡(關鍵字: 快樂 爵士)
#
# 🎵 正在抓取: 開心的早晨🎶我們來聽音樂吧 (關鍵字: 快樂 藍調)
#
# 🎵 正在抓取: A-Lin 精選熱門歌曲(關鍵字: 快樂 藍調)
#
# 🎵 正在抓取: 五月天熱門歌曲！(關鍵字: 快樂 藍調)
#
# 🎵 正在抓取: 煙嗓情歌(關鍵字: 快樂 藍調)
#
# 🎵 正在抓取: 愛唱歌親子演唱會《米卡勇闖魔法夢奇地》(關鍵字: 快樂 藍調)
#
# 🎵 正在抓取: 最好聽粵語廣東歌曲 Best Cantonese Songs(關鍵字: 快樂 舞曲)
#
# 🎵 正在抓取: Bossa Nova｜慵懒风情(關鍵字: 快樂 舞曲)
#
# 🎵 正在抓取: 蔡依林 Jolin Tsai | 必聽精選 TOP HITS(關鍵字: 快樂 舞曲)
#
# 🎵 正在抓取: 樂齡輕快舞曲(關鍵字: 快樂 舞曲)
#
# 🎵 正在抓取: 快樂舞曲(關鍵字: 快樂 舞曲)
#
# 🎵 正在抓取: ⛺️凹豆咖快看！ 露營放鬆的⚡️鄉村搖滾樂 (2)(關鍵字: 快樂 鄉村)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 快樂 靈魂)
#
# 🎵 正在抓取: 夏日音樂廳(關鍵字: 快樂 靈魂)
#
# 🎵 正在抓取: 靈魂男聲 山姆史密斯 Sam Smith 生日快樂！(關鍵字: 快樂 靈魂)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 快樂 靈魂)
#
# 🎵 正在抓取: 台灣FM電台 JAMZ 95 | Taiwan's No.1 R&B Station(關鍵字: 快樂 靈魂)
#
# 🎵 正在抓取: 滾石40撞樂隊 翻唱與原唱 完整合輯(關鍵字: 快樂 吉他)
#
# 🎵 正在抓取: Taiwanese Bands(關鍵字: 快樂 吉他)
#
# 🎵 正在抓取: Mavis Hee - Greatest Hits 許美靜/许美静 精选(關鍵字: 快樂 吉他)
#
# 🎵 正在抓取: 寶寶睡眠鋼琴 輕柔旋律入夢鄉 Babe Sleep Piano Lullaby with Soothing Melody(關鍵字: 快樂 環境音樂)
#
# 🎵 正在抓取: 高端渣女 開車必聽(關鍵字: 快樂 獨立音樂)
#
# 🎵 正在抓取: 最爱情歌90-世纪情歌超级精选(關鍵字: 愛情 流行)
#
# 🎵 正在抓取: 想了不只幾百次(關鍵字: 愛情 流行)
#
# 🎵 正在抓取: 2000-2010 千鿋年廣東歌 (關鍵字: 愛情 流行)
#
# 🎵 正在抓取: 流行愛情 Pop Love(關鍵字: 愛情 流行)
#
# 🎵 正在抓取: 愛情這回事 (Always Need Love Songs)(關鍵字: 愛情 流行)
#
# 🎵 正在抓取: 嘻哈愛情(關鍵字: 愛情 嘻哈)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 愛情 嘻哈)
#
# 🎵 正在抓取: 想了不只幾百次(關鍵字: 愛情 嘻哈)
#
# 🎵 正在抓取: 陪我做個80年代的神通情人夢（Electric Dreams 1984）(關鍵字: 愛情 電子)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 愛情 電子)
#
# 🎵 正在抓取: 2000-2010 千鿋年廣東歌 (關鍵字: 愛情 電子)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 愛情 民謠)
#
# 🎵 正在抓取: 日劇超經典 – Japanese Drama Songs Collection (關鍵字: 愛情 藍調)
#
# 🎵 正在抓取: 蔡健雅 _情歌精選(關鍵字: 愛情 藍調)
#
# 🎵 正在抓取: 孫燕姿AUT NIHILO 就在日落以後巡迴演唱會 STEFANIE SUN YANZI 孙燕姿就在日落以后(關鍵字: 愛情 藍調)
#
# 🎵 正在抓取: 1990-2010s華語金曲(關鍵字: 愛情 藍調)
#
# 🎵 正在抓取: 2000-2010華語歌壇聖經(關鍵字: 愛情 藍調)
#
# 🎵 正在抓取: 日劇超經典 – Japanese Drama Songs Collection (關鍵字: 愛情 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 愛情 R&B)
#
# 🎵 正在抓取: 梁文音｜情歌精選(關鍵字: 愛情 R&B)
#
# 🎵 正在抓取: 蕭亞軒 ELVA HSIAO | 必聽精選TOP HITS(關鍵字: 愛情 舞曲)
#
# 🎵 正在抓取: 愛情少尉舞曲集(關鍵字: 愛情 舞曲)
#
# 🎵 正在抓取: 2023臺北眷村文化節-家(關鍵字: 愛情 鄉村)
#
# 🎵 正在抓取: 祕密花園OST(關鍵字: 愛情 靈魂)
#
# 🎵 正在抓取: 時代少年團     TF3代   T.O.P登陸少年組合（all ）（我把ㄧ些無法播放的音檔刪了所以現在變成只有67小時多而已）(關鍵字: 愛情 靈魂)
#
# 🎵 正在抓取: 純真博物館(關鍵字: 愛情 靈魂)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 愛情 靈魂)
#
# 🎵 正在抓取: 林夕：哥哥字傳(關鍵字: 愛情 靈魂)
#
# 🎵 正在抓取: [KKBOX]ㄧ個人的孤單，靜靜地聽歌就沒事了。 / 2024-12-27(關鍵字: 愛情 鋼琴)
#
# 🎵 正在抓取: 《長風渡》影視劇原聲帶(關鍵字: 愛情 吉他)
#
# 🎵 正在抓取: 情歌大全：致美好的愛情(關鍵字: 愛情 吉他)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 愛情 獨立音樂)
#
# 🎵 正在抓取: 最好聽台灣流行歌曲 Best Taiwanese Pop Songs(關鍵字: 能量 搖滾)
#
# 🎵 正在抓取: 日本搖滾(關鍵字: 能量 搖滾)
#
# 🎵 正在抓取: 俺のロックだ🎸(關鍵字: 能量 搖滾)
#
# 🎵 正在抓取: 台灣獨立樂團(關鍵字: 能量 搖滾)
#
# 🎵 正在抓取: 椎名林檎代表作(關鍵字: 能量 搖滾)
#
# 🎵 正在抓取: 大嘻哈時代2(關鍵字: 能量 嘻哈)
#
# 🎵 正在抓取: K-HIPHOP (korean rap)(關鍵字: 能量 嘻哈)
#
# 🎵 正在抓取: Xmaswu 吳驁💫(關鍵字: 能量 嘻哈)
#
# 🎵 正在抓取: HipHop 🤬🔫(關鍵字: 能量 嘻哈)
#
# 🎵 正在抓取: 中文嘻哈能量(關鍵字: 能量 嘻哈)
#
# 🎵 正在抓取: 陪讀電子音 (2)(關鍵字: 能量 電子)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 能量 電子)
#
# 🎵 正在抓取: 椎名林檎代表作(關鍵字: 能量 電子)
#
# 🎵 正在抓取: ELECTRONIC CONCENTRATION(關鍵字: 能量 電子)
#
# 🎵 正在抓取: TOOL(關鍵字: 能量 電子)
#
# 🎵 正在抓取: NO, THIS is 鳳飛飛（不，這才是鳳飛飛）—歌林篇(關鍵字: 能量 民謠)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 能量 民謠)
#
# 🎵 正在抓取: 卡拉揚-指揮帝王 Karajan Forever(關鍵字: 能量 古典)
#
# 🎵 正在抓取: DG古典．百年經典(關鍵字: 能量 古典)
#
# 🎵 正在抓取: 是春天了呀～(關鍵字: 能量 古典)
#
# 🎵 正在抓取: 周傑倫中國風歌曲全收錄(關鍵字: 能量 古典)
#
# 🎵 正在抓取: Lucky Dube - THE GREATEST HITS(關鍵字: 能量 古典)
#
# 🎵 正在抓取: 中文爵士流行歌曲 2024 Chinese Pop Jazz(關鍵字: 能量 爵士)
#
# 🎵 正在抓取: 第1章 現在聽爵士樂正合時(關鍵字: 能量 爵士)
#
# 🎵 正在抓取: 第4章 10種爵士樂風格(關鍵字: 能量 爵士)
#
# 🎵 正在抓取: Jazz Diva爵美女聲(關鍵字: 能量 爵士)
#
# 🎵 正在抓取: Nathanology presents: Aroma Deep House 002(關鍵字: 能量 爵士)
#
# 🎵 正在抓取: 1990-2010s華語金曲(關鍵字: 能量 藍調)
#
# 🎵 正在抓取: 2000-2010華語歌壇聖經(關鍵字: 能量 藍調)
#
# 🎵 正在抓取: 最爱情歌90-世纪情歌超级精选(關鍵字: 能量 藍調)
#
# 🎵 正在抓取: 頌缽、梵文大休息曲(關鍵字: 能量 藍調)
#
# 🎵 正在抓取: 卡拉揚-指揮帝王 Karajan Forever(關鍵字: 能量 藍調)
#
# 🎵 正在抓取: 最好聽粵語廣東歌曲 Best Cantonese Songs(關鍵字: 能量 舞曲)
#
# 🎵 正在抓取:  粵語 勁歌 舞曲 女版 I (電音女王篇) CantoDance  Part 1  1980s-1990s Female(關鍵字: 能量 舞曲)
#
# 🎵 正在抓取: 高能量舞曲(關鍵字: 能量 舞曲)
#
# 🎵 正在抓取: 华语流行音乐精选(關鍵字: 能量 舞曲)
#
# 🎵 正在抓取: 最好聽粵語廣東歌曲 Best Cantonese Songs(關鍵字: 能量 舞曲)
#
# 🎵 正在抓取: 重金屬搖滾樂(關鍵字: 能量 重金屬)
#
# 🎵 正在抓取: 重金屬 嘶吼(關鍵字: 能量 重金屬)
#
# 🎵 正在抓取: 節奏感很強的好歌(關鍵字: 能量 重金屬)
#
# 🎵 正在抓取: 2023臺北眷村文化節-家(關鍵字: 能量 鄉村)
#
# 🎵 正在抓取: 夏日音樂廳(關鍵字: 能量 靈魂)
#
# 🎵 正在抓取: 心靈安定劑(關鍵字: 能量 靈魂)
#
# 🎵 正在抓取: Jazz Diva爵美女聲(關鍵字: 能量 靈魂)
#
# 🎵 正在抓取: 編輯情境題：望著天花板的凌晨三點半(關鍵字: 能量 靈魂)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 能量 靈魂)
#
# 🎵 正在抓取: 周杰倫《嘉年華》2025世界巡迴演唱會 歌單 搶先聽 Jay Chou Carnival World Tour 2025 Setlist(關鍵字: 能量 吉他)
#
# 🎵 正在抓取: 動畫歌曲*咒迴，鬼滅，火影，迪士尼，吉卜力，巨人，獵人，伍六七，天官，肌肉魔法使，我推の子，怪獸8號，hazbin...*(關鍵字: 能量 吉他)
#
# 🎵 正在抓取: 轻柔吉他(關鍵字: 能量 吉他)
#
# 🎵 正在抓取: 天使靈氣+冥想音樂(關鍵字: 能量 環境音樂)
#
# 🎵 正在抓取: 自律神經放鬆(關鍵字: 能量 環境音樂)
#
# 🎵 正在抓取: 人選之人—造浪者 (Netflix 臺灣原創影集 影集原聲帶)(關鍵字: 能量 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 能量 獨立音樂)
#
# 🎵 正在抓取: 「失序場」不藏私音樂清單(關鍵字: 能量 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團 - 2024(關鍵字: 能量 獨立音樂)
#
# 🎵 正在抓取: 赤瞳音樂精選 I RUBY EYES  RECORDS(關鍵字: 能量 獨立音樂)
#
# 🎵 正在抓取: 經典華語歌曲(關鍵字: 懷舊 流行)
#
# 🎵 正在抓取: 台語懷舊老歌(關鍵字: 懷舊 流行)
#
# 🎵 正在抓取: 流行英語歌曲(關鍵字: 懷舊 流行)
#
# 🎵 正在抓取: 永遠懷念黃鴻升(關鍵字: 懷舊 流行)
#
# 🎵 正在抓取: 復古港風(關鍵字: 懷舊 流行)
#
# 🎵 正在抓取: 經典華語歌曲(關鍵字: 懷舊 搖滾)
#
# 🎵 正在抓取: 流行英語歌曲(關鍵字: 懷舊 搖滾)
#
# 🎵 正在抓取: 懷舊爵士(關鍵字: 懷舊 爵士)
# ❌ 抓取失敗，錯誤: sequence item 0: expected str instance, NoneType found
#
# 🎵 正在抓取: Retro Chinese City Pop: 復古風中文城市流行 中文citypop(關鍵字: 懷舊 爵士)
#
# 🎵 正在抓取: 愛情長跑懷舊歌(關鍵字: 懷舊 藍調)
#
# 🎵 正在抓取: 懷舊抒情英文老歌(關鍵字: 懷舊 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 懷舊 R&B)
#
# 🎵 正在抓取: 台語懷舊老歌 2022年 回憶藏歌(關鍵字: 懷舊 R&B)
#
# 🎵 正在抓取: 爵士 + R&B + 慵懶(關鍵字: 懷舊 R&B)
#
# 🎵 正在抓取: 70、80民歌、國語懷舊歌曲(關鍵字: 懷舊 R&B)
#
# 🎵 正在抓取: 80年代 夜店舞曲 1980s Club Music(關鍵字: 懷舊 舞曲)
#
# 🎵 正在抓取: 懷舊國語舞曲(關鍵字: 懷舊 舞曲)
#
# 🎵 正在抓取: 懷舊英文舞曲(關鍵字: 懷舊 舞曲)
#
# 🎵 正在抓取: 懷舊、舞曲、夜店(關鍵字: 懷舊 舞曲)
#
# 🎵 正在抓取: 懷舊英文舞曲(關鍵字: 懷舊 舞曲)
#
# 🎵 正在抓取: 六、七年級懷舊金曲老歌(關鍵字: 懷舊 重金屬)
#
# 🎵 正在抓取: 重金屬搖滾樂(關鍵字: 懷舊 重金屬)
#
# 🎵 正在抓取: 經典台語老歌(關鍵字: 懷舊 重金屬)
#
# 🎵 正在抓取: KTV嗨歌-high起來(關鍵字: 懷舊 重金屬)
#
# 🎵 正在抓取: 重金屬 嘶吼(關鍵字: 懷舊 重金屬)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 懷舊 環境音樂)
#
# 🎵 正在抓取: 六、七年級懷舊金曲老歌(關鍵字: 懷舊 環境音樂)
#
# 🎵 正在抓取: 懷舊抒情英文老歌(關鍵字: 懷舊 環境音樂)
#
# 🎵 正在抓取: 深層放鬆。背景樂(關鍵字: 懷舊 環境音樂)
#
# 🎵 正在抓取: 經典台語老歌(關鍵字: 懷舊 環境音樂)
#
# 🎵 正在抓取: 英文流行钢琴曲 2025 Popular Piano Music(關鍵字: 學習 流行)
#
# 🎵 正在抓取: 英文流行鋼琴曲 Pop Piano Covers(關鍵字: 學習 流行)
#
# 🎵 正在抓取: 治愈中英文流行鋼琴音樂 Soothing Piano Cover Mandarin & English Pop Songs 🎹(關鍵字: 學習 流行)
#
# 🎵 正在抓取: TikTokで流行ったボカロ曲(關鍵字: 學習 流行)
#
# 🎵 正在抓取: 香港流行音樂鋼琴曲 Cantopop Hong Kong Pop Piano Instrumental(關鍵字: 學習 流行)
#
# 🎵 正在抓取: HappyRuff 狗-放鬆軟搖(關鍵字: 學習 搖滾)
#
# 🎵 正在抓取: 歌詞なしEDM（勉強用）(關鍵字: 學習 電子)
#
# 🎵 正在抓取: 古典 - 學習(關鍵字: 學習 古典)
#
# 🎵 正在抓取: 我的古典學習地圖(關鍵字: 學習 古典)
#
# 🎵 正在抓取: 古典學習(關鍵字: 學習 古典)
#
# 🎵 正在抓取: 古典反派的學習時間(關鍵字: 學習 古典)
#
# 🎵 正在抓取: For Swing Beginner(關鍵字: 學習 爵士)
#
# 🎵 正在抓取: 爵士BGM專注學習指南(關鍵字: 學習 爵士)
#
# 🎵 正在抓取: 跟著🅐🅛🅘好好玩《創意鍵盤》圈圈Ｉ(關鍵字: 學習 藍調)
#
# 🎵 正在抓取: 跟著🅐🅛🅘好好玩《創意鍵盤》疊疊Ｉ(關鍵字: 學習 藍調)
#
# 🎵 正在抓取: 二十首你該學習與聽熟「帶有藍調旋律」的Jazz Standard(關鍵字: 學習 藍調)
#
# 🎵 正在抓取: 超・乃木坂スター誕生！LIVE2024予習用(關鍵字: 學習 藍調)
#
# 🎵 正在抓取: 英文流行钢琴曲 2025 Popular Piano Music(關鍵字: 學習 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 學習 R&B)
#
# 🎵 正在抓取: ヨルシカ  全曲  ( リリース順 )(關鍵字: 學習 R&B)
#
# 🎵 正在抓取: R&B 英韓節奏藍調🦌(關鍵字: 學習 R&B)
#
# 🎵 正在抓取: BGM / MUJI 無印良品(關鍵字: 學習 R&B)
#
# 🎵 正在抓取: HappyRuff 狗-放鬆雷鬼(關鍵字: 學習 雷鬼)
#
# 🎵 正在抓取: Happy Ruff 狗-放鬆雷鬼 vol.2(關鍵字: 學習 雷鬼)
#
# 🎵 正在抓取: Metal Study(關鍵字: 學習 重金屬)
#
# 🎵 正在抓取: Heavy Metal Training(關鍵字: 學習 重金屬)
#
# 🎵 正在抓取: 讀書音樂 沉浸式學習音樂 專注力提升Study with Me(關鍵字: 學習 環境音樂)
#
# 🎵 正在抓取: 跟著🅐🅛🅘好好玩《創意鍵盤》圈圈Ｉ(關鍵字: 學習 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 學習 獨立音樂)
#
# 🎵 正在抓取: 跟著🅐🅛🅘好好玩《創意鍵盤》疊疊Ｉ(關鍵字: 學習 獨立音樂)
# ⚠️ 讀取超時!等待5秒後重試...(offset=0)
#
# 🎵 正在抓取: 讀書音樂 沉浸式學習音樂 專注力提升Study with Me(關鍵字: 學習 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團 - 2024(關鍵字: 學習 獨立音樂)
#
# 🎵 正在抓取: 911 玖壹壹 (關鍵字: 運動 流行)
#
# 🎵 正在抓取: 炸音響快歌(關鍵字: 運動 流行)
#
# 🎵 正在抓取: 911 玖壹壹 大合輯(關鍵字: 運動 流行)
#
# 🎵 正在抓取: 中華隊12強必聽熱血(關鍵字: 運動 流行)
#
# 🎵 正在抓取: 羅志祥快歌串燒(關鍵字: 運動 流行)
#
# 🎵 正在抓取: 聽日搖提神 ✊ 讓你熱血沸騰的J-Rock⚡️(關鍵字: 運動 搖滾)
#
# 🎵 正在抓取: 中文慢搖滾 適合運動後緩和(關鍵字: 運動 搖滾)
#
# 🎵 正在抓取: 運動搖滾(關鍵字: 運動 搖滾)
#
# 🎵 正在抓取: 搖滾運動(關鍵字: 運動 搖滾)
#
# 🎵 正在抓取: Madchester Rave On︱Best of Madchester & Baggy(關鍵字: 運動 搖滾)
#
# 🎵 正在抓取: 911 玖壹壹 (關鍵字: 運動 嘻哈)
#
# 🎵 正在抓取: 炸音響快歌(關鍵字: 運動 嘻哈)
#
# 🎵 正在抓取: 911 玖壹壹 大合輯(關鍵字: 運動 嘻哈)
#
# 🎵 正在抓取: 西洋嘻哈HIGH喔(關鍵字: 運動 嘻哈)
#
# 🎵 正在抓取: 運動嘻哈(關鍵字: 運動 嘻哈)
#
# 🎵 正在抓取: 電子遊戲 Video Game(關鍵字: 運動 電子)
#
# 🎵 正在抓取: LEGIÃO REMIX(關鍵字: 運動 電子)
#
# 🎵 正在抓取: 北歐櫥窗 × 林貓王：好自在的居家音樂(關鍵字: 運動 民謠)
#
# 🎵 正在抓取: 《Jazz Club for Beginners》可以跟著跳舞的爵士樂合輯(關鍵字: 運動 爵士)
#
# 🎵 正在抓取: 《Blue Bossa》充滿濃烈律動感的爵士樂(關鍵字: 運動 爵士)
#
# 🎵 正在抓取: 911 玖壹壹 (關鍵字: 運動 R&B)
#
# 🎵 正在抓取: Dance to Jolin 蔡依林舞曲(關鍵字: 運動 舞曲)
#
# 🎵 正在抓取: 健身良伴熱門舞曲混音（2019.2.13更新） by DJ Rainbowchild(關鍵字: 運動 舞曲)
#
# 🎵 正在抓取: 運動舞曲(關鍵字: 運動 舞曲)
#
# 🎵 正在抓取: 運動健身有氧動感舞曲(關鍵字: 運動 舞曲)
#
# 🎵 正在抓取: 運動舞曲(關鍵字: 運動 舞曲)
#
# 🎵 正在抓取: 重金屬 嘶吼(關鍵字: 運動 重金屬)
#
# 🎵 正在抓取: 健身專用🍑(關鍵字: 運動 重金屬)
#
# 🎵 正在抓取: 聽不膩的西洋嗨歌舞曲⚡️(關鍵字: 運動 重金屬)
#
# 🎵 正在抓取: 重金屬(關鍵字: 運動 重金屬)
#
# 🎵 正在抓取: 開車聽的華語嘻哈(關鍵字: 運動 重金屬)
#
# 🎵 正在抓取: 運動時聽音樂(關鍵字: 運動 環境音樂)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 運動 環境音樂)
#
# 🎵 正在抓取: 節奏感很強的好歌(關鍵字: 運動 環境音樂)
#
# 🎵 正在抓取: 深層放鬆。背景樂(關鍵字: 運動 環境音樂)
#
# 🎵 正在抓取: 自律神經放鬆(關鍵字: 運動 環境音樂)
#
# 🎵 正在抓取: 北歐櫥窗 × 林貓王：好自在的居家音樂(關鍵字: 運動 獨立音樂)
#
# 🎵 正在抓取: 開車輕搖滾(關鍵字: 開車 搖滾)
#
# 🎵 正在抓取: 開車聽中文精選(關鍵字: 開車 搖滾)
#
# 🎵 正在抓取: 2025抒情搖滾開車聽(關鍵字: 開車 搖滾)
#
# 🎵 正在抓取: 開車聽的華語嘻哈(關鍵字: 開車 嘻哈)
#
# 🎵 正在抓取: 高端渣男開車把妹歌單(關鍵字: 開車 嘻哈)
#
# 🎵 正在抓取: 鄉村嘻哈饒舌開車聽(關鍵字: 開車 嘻哈)
#
# 🎵 正在抓取: [Lucius']🚓Carplay▶(關鍵字: 開車 嘻哈)
#
# 🎵 正在抓取: SUNDAY MORNING REGGAE(關鍵字: 開車 古典)
#
# 🎵 正在抓取: 開車古典與跨界(關鍵字: 開車 古典)
#
# 🎵 正在抓取: 藍調開車輕音樂(關鍵字: 開車 藍調)
#
# 🎵 正在抓取: 我的 Tokyo City Pop (1975-2022)(關鍵字: 開車 藍調)
#
# 🎵 正在抓取: Chen Yinn: Continental Breakfast at 11AM(關鍵字: 開車 藍調)
#
# 🎵 正在抓取: 開車超帶勁｜低音砲誰不愛(關鍵字: 開車 藍調)
#
# 🎵 正在抓取: 開車舞曲(關鍵字: 開車 舞曲)
#
# 🎵 正在抓取: 開車舞曲(關鍵字: 開車 舞曲)
#
# 🎵 正在抓取: 開車絕對唱到醒 (關鍵字: 開車 重金屬)
#
# 🎵 正在抓取: 開車聽的華語嘻哈(關鍵字: 開車 重金屬)
#
# 🎵 正在抓取: 重金屬 嘶吼(關鍵字: 開車 重金屬)
#
# 🎵 正在抓取: 開車電台(中文選集)(關鍵字: 開車 重金屬)
#
# 🎵 正在抓取: 深夜EMO歌單😭(關鍵字: 開車 重金屬)
#
# 🎵 正在抓取: 鄉村嘻哈饒舌開車聽(關鍵字: 開車 鄉村)
#
# 🎵 正在抓取: 開車路上：鄉村詩歌敬拜 Roadtrip Worship - Country Vibe(關鍵字: 開車 鄉村)
#
# 🎵 正在抓取: Classic Soul 經典靈魂樂(關鍵字: 開車 靈魂)
#
# 🎵 正在抓取: VOGUE人生歌單(關鍵字: 開車 靈魂)
#
# 🎵 正在抓取: 高端渣女 開車必聽(關鍵字: 開車 獨立音樂)
#
# 🎵 正在抓取: 讀書 工作背景音樂： 流行鋼琴 輕音樂BGM  Best Pop Piano Cover for Study and work time(關鍵字: 專注 流行)
#
# 🎵 正在抓取: 治愈中英文流行鋼琴音樂 Soothing Piano Cover Mandarin & English Pop Songs 🎹(關鍵字: 專注 流行)
#
# 🎵 正在抓取: 大熱門猜歌王完整版(關鍵字: 專注 流行)
#
# 🎵 正在抓取: 台灣流行音樂200最佳專輯（1975-1993）（陶曉清、馬世芳、葉雲平）(關鍵字: 專注 流行)
#
# 🎵 正在抓取: 安靜的稻草人(關鍵字: 專注 流行)
#
# 🎵 正在抓取: hyukoh_style(關鍵字: 專注 搖滾)
#
# 🎵 正在抓取: DREAM  POP(關鍵字: 專注 搖滾)
#
# 🎵 正在抓取: 乾淨的髒｜英倫搖滾與專注背景音(關鍵字: 專注 搖滾)
#
# 🎵 正在抓取: 安靜的稻草人(關鍵字: 專注 嘻哈)
#
# 🎵 正在抓取: Hip-Hop / Rap(關鍵字: 專注 嘻哈)
#
# 🎵 正在抓取: 專注工作(輕電子)(關鍵字: 專注 電子)
#
# 🎵 正在抓取: Psychedelic 快節奏大麻迷幻電子音樂 專注工作 (關鍵字: 專注 電子)
#
# 🎵 正在抓取: 電音合輯: K-POP 中的電子音樂 (Electronic Music in K-Pop)(關鍵字: 專注 電子)
#
# 🎵 正在抓取: NO, THIS is 鳳飛飛（不，這才是鳳飛飛）—歌林篇(關鍵字: 專注 民謠)
#
# 🎵 正在抓取: 讀書用的專注音樂 輕音樂古典 Focus Music for Study(關鍵字: 專注 古典)
#
# 🎵 正在抓取: 晨間專注：古典提神(關鍵字: 專注 古典)
#
# 🎵 正在抓取: 專注古典&爵士Music for Work & Study(關鍵字: 專注 古典)
#
# 🎵 正在抓取: 古典｜低音大提琴賞析(關鍵字: 專注 古典)
#
# 🎵 正在抓取: 專注古典樂(關鍵字: 專注 古典)
#
# 🎵 正在抓取: 咖啡廳必備 微醺放鬆爵士樂(關鍵字: 專注 爵士)
#
# 🎵 正在抓取: 專注古典&爵士Music for Work & Study(關鍵字: 專注 爵士)
#
# 🎵 正在抓取: 古典｜低音大提琴賞析(關鍵字: 專注 爵士)
#
# 🎵 正在抓取: Nathanology presents: Aroma Deep House 002(關鍵字: 專注 爵士)
#
# 🎵 正在抓取: 爵士BGM專注學習指南(關鍵字: 專注 爵士)
#
# 🎵 正在抓取: 五月天熱門歌曲！(關鍵字: 專注 藍調)
#
# 🎵 正在抓取: 聽了直接不專心(關鍵字: 專注 藍調)
#
# 🎵 正在抓取: 中文藍調專輯(關鍵字: 專注 藍調)
#
# 🎵 正在抓取: 《櫻蘭高校男公關部》原聲帶精選(關鍵字: 專注 藍調)
#
# 🎵 正在抓取: My top 10 of metal band(關鍵字: 專注 藍調)
#
# 🎵 正在抓取: 周杰倫激推經典神曲 TOP 50！(關鍵字: 專注 R&B)
#
# 🎵 正在抓取: 重金屬搖滾樂(關鍵字: 專注 重金屬)
#
# 🎵 正在抓取: 鋼琴純音 放鬆舒心輕音樂 (工作/讀書/專注/療癒) Piano Music for Relax & Focus Moment(關鍵字: 專注 鋼琴)
#
# 🎵 正在抓取: 鋼琴輕音樂 療癒森林 自然系專注純音樂(關鍵字: 專注 鋼琴)
#
# 🎵 正在抓取: 鋼琴放鬆輕聽 咖啡廳 專注 讀書音樂(關鍵字: 專注 鋼琴)
#
# 🎵 正在抓取: 深度專注-聆聽環境音樂 7.5Hr Listen to Ambient Music Long GC - 播放清單(關鍵字: 專注 環境音樂)
#
# 🎵 正在抓取: 深層放鬆。背景樂(關鍵字: 專注 環境音樂)
#
# 🎵 正在抓取: 讀書音樂 沉浸式學習音樂 專注力提升Study with Me(關鍵字: 專注 環境音樂)
#
# 🎵 正在抓取: 讀書工作鋼琴音樂studying working piano music(關鍵字: 專注 獨立音樂)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 派對 搖滾)
#
# 🎵 正在抓取: 蘇慧倫 – 30週年值得3CD精選(關鍵字: 派對 搖滾)
#
# 🎵 正在抓取: 俺のロックだ🎸(關鍵字: 派對 搖滾)
#
# 🎵 正在抓取: 歡樂 派對 電子 搖滾樂(關鍵字: 派對 搖滾)
#
# 🎵 正在抓取: Let's Walk in Fussa!(關鍵字: 派對 搖滾)
#
# 🎵 正在抓取: 西洋嘻哈派對金曲(關鍵字: 派對 嘻哈)
#
# 🎵 正在抓取: 中文華語嘻哈饒舌金曲(關鍵字: 派對 嘻哈)
#
# 🎵 正在抓取: 嘻哈派對(關鍵字: 派對 嘻哈)
#
# 🎵 正在抓取: 嘻哈派對3/5(關鍵字: 派對 嘻哈)
#
# 🎵 正在抓取: 嘻哈派對(關鍵字: 派對 嘻哈)
#
# 🎵 正在抓取: 1͜͝8͜͝t͜͝i͜͝f͜͝y͜͝⓹百大混音⓹ 醉愛P̾̾a̾r̾t̾y̾夜店𝔻𝕁 ʍïẍ，經典舞曲絕對動感嗨翻你的派對(關鍵字: 派對 電子)
#
# 🎵 正在抓取: Contemporary classical music(關鍵字: 派對 電子)
#
# 🎵 正在抓取: 2000-2010 千鿋年廣東歌 (關鍵字: 派對 電子)
#
# 🎵 正在抓取: 歡樂 派對 電子 搖滾樂(關鍵字: 派對 電子)
#
# 🎵 正在抓取: 電子舞曲/派對(關鍵字: 派對 電子)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 派對 民謠)
#
# 🎵 正在抓取: 卡拉揚-指揮帝王 Karajan Forever(關鍵字: 派對 古典)
#
# 🎵 正在抓取: 是春天了呀～(關鍵字: 派對 古典)
#
# 🎵 正在抓取: Contemporary classical music(關鍵字: 派對 古典)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 派對 爵士)
#
# 🎵 正在抓取: Contemporary classical music(關鍵字: 派對 爵士)
#
# 🎵 正在抓取: 蘇慧倫 – 30週年值得3CD精選(關鍵字: 派對 藍調)
#
# 🎵 正在抓取: 卡拉揚-指揮帝王 Karajan Forever(關鍵字: 派對 藍調)
#
# 🎵 正在抓取: 國語兒歌(關鍵字: 派對 藍調)
#
# 🎵 正在抓取: 致那些在暖男時代比較吃虧的暖女們(關鍵字: 派對 藍調)
#
# 🎵 正在抓取: 台灣BL OST (關鍵字: 派對 藍調)
#
# 🎵 正在抓取: 百大DJ - 2025(關鍵字: 派對 舞曲)
#
# 🎵 正在抓取: 蘇慧倫 – 30週年值得3CD精選(關鍵字: 派對 舞曲)
#
# 🎵 正在抓取: DJ 慢搖remix 舞曲蹦蹦夜店八神抖音派對不停吃毒搖 一條K到想飛喇叭吹(關鍵字: 派對 舞曲)
#
# 🎵 正在抓取: 2022百大DJ電音(關鍵字: 派對 舞曲)
#
# 🎵 正在抓取: 1͜͝8͜͝t͜͝i͜͝f͜͝y͜͝⓹百大混音⓹ 醉愛P̾̾a̾r̾t̾y̾夜店𝔻𝕁 ʍïẍ，經典舞曲絕對動感嗨翻你的派對(關鍵字: 派對 舞曲)
#
# 🎵 正在抓取: 鄉村派對(關鍵字: 派對 鄉村)
#
# 🎵 正在抓取: 致那些在暖男時代比較吃虧的暖女們(關鍵字: 派對 靈魂)
#
# 🎵 正在抓取: 時代少年團     TF3代   T.O.P登陸少年組合（all ）（我把ㄧ些無法播放的音檔刪了所以現在變成只有67小時多而已）(關鍵字: 派對 靈魂)
#
# 🎵 正在抓取: ㄧ個人的孤單，靜靜地聽歌就沒事了。 #獨處 #安靜(關鍵字: 派對 鋼琴)
#
# 🎵 正在抓取: [KKBOX]ㄧ個人的孤單，靜靜地聽歌就沒事了。 / 2024-12-27(關鍵字: 派對 鋼琴)
#
# 🎵 正在抓取: Animation songs（日本動畫歌）(關鍵字: 派對 鋼琴)
#
# 🎵 正在抓取: Piano Talk 鋼琴說話(關鍵字: 派對 鋼琴)
#
# 🎵 正在抓取: 心碎時，田馥甄 Hebe 的情歌陪我療傷💔(關鍵字: 派對 吉他)
#
# 🎵 正在抓取: Let's Walk in Fussa!(關鍵字: 派對 獨立音樂)
#
# 🎵 正在抓取: 睡覺音樂(關鍵字: 睡覺 流行)
#
# 🎵 正在抓取: 睡覺古典(關鍵字: 睡覺 古典)
#
# 🎵 正在抓取: 貓咪 狗狗 放鬆睡覺音樂 紓壓安撫 毛小孩陪伴音樂 Soothing Music for Cat  & Dog Sleep(關鍵字: 睡覺 古典)
#
# 🎵 正在抓取: 古典睡覺音樂(關鍵字: 睡覺 古典)
#
# 🎵 正在抓取: 睡覺前聽的古典樂(關鍵字: 睡覺 古典)
#
# 🎵 正在抓取: 古典睡覺(關鍵字: 睡覺 古典)
#
# 🎵 正在抓取: 你啊你啊(關鍵字: 睡覺 藍調)
#
# 🎵 正在抓取: 輕·藍調·睡覺·讀書(關鍵字: 睡覺 藍調)
# ❌ 抓取失敗，錯誤: sequence item 0: expected str instance, NoneType found
#
# 🎵 正在抓取: 抖音DJ版歌🤍🖤(關鍵字: 睡覺 R&B)
#
# 🎵 正在抓取: 適合睡覺的英文歌 (關鍵字: 睡覺 R&B)
#
# 🎵 正在抓取: 宮崎駿睡覺(關鍵字: 睡覺 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 睡覺 R&B)
#
# 🎵 正在抓取: 抖音DJ版歌 🖤(關鍵字: 睡覺 R&B)
#
# 🎵 正在抓取: 適合睡覺的英文歌 (關鍵字: 睡覺 重金屬)
#
# 🎵 正在抓取: 睡前輕音樂(關鍵字: 睡覺 重金屬)
#
# 🎵 正在抓取: 深度睡眠 |重度失眠者专用歌单(關鍵字: 睡覺 重金屬)
#
# 🎵 正在抓取: 鋼琴睡覺(關鍵字: 睡覺 鋼琴)
#
# 🎵 正在抓取: 鋼琴音樂（讀書、睡覺、放鬆）(關鍵字: 睡覺 鋼琴)
#
# 🎵 正在抓取: 鋼琴鋼琴睡覺用(關鍵字: 睡覺 鋼琴)
#
# 🎵 正在抓取: 小後苑睡覺歌單（鋼琴）(關鍵字: 睡覺 鋼琴)
#
# 🎵 正在抓取: 適合睡覺的英文歌 (關鍵字: 睡覺 環境音樂)
#
# 🎵 正在抓取: 睡前輕音樂(關鍵字: 睡覺 環境音樂)
#
# 🎵 正在抓取: 適合睡覺的英文歌 (關鍵字: 睡覺 獨立音樂)
#
# 🎵 正在抓取: 睡前輕音樂(關鍵字: 睡覺 獨立音樂)
#
# 🎵 正在抓取: 中文流行咖啡純音樂 Mandarin Pop Coffee Music 🎹(關鍵字: 咖啡 流行)
#
# 🎵 正在抓取: 鋼琴閱讀咖啡廳 輕音樂華語流行 古典樂大師合輯(關鍵字: 咖啡 流行)
#
# 🎵 正在抓取: 中文流行咖啡純音樂 Mandarin Pop Coffee Music 🎹(關鍵字: 咖啡 流行)
#
# 🎵 正在抓取: :: 𝑪𝑶𝑭𝑭𝑬𝑬 — 𝑺𝑯𝑶𝑷 ::(關鍵字: 咖啡 搖滾)
#
# 🎵 正在抓取: ☕️(關鍵字: 咖啡 電子)
# ❌ 抓取失敗，錯誤: sequence item 0: expected str instance, NoneType found
#
# 🎵 正在抓取: 旭舊咖啡廳歌單(關鍵字: 咖啡 民謠)
#
# 🎵 正在抓取: 咖啡廳民謠(關鍵字: 咖啡 民謠)
#
# 🎵 正在抓取: 鋼琴閱讀咖啡廳 輕音樂華語流行 古典樂大師合輯(關鍵字: 咖啡 古典)
#
# 🎵 正在抓取: 鋼琴爵士古典午茶 宮崎駿代表作 咖啡廳最愛播的(關鍵字: 咖啡 古典)
#
# 🎵 正在抓取: WFH 在家上班輕古典(關鍵字: 咖啡 古典)
#
# 🎵 正在抓取: ☕️有朝一日的咖啡馆(關鍵字: 咖啡 古典)
#
# 🎵 正在抓取: 咖啡店柔和的爵士(關鍵字: 咖啡 爵士)
#
# 🎵 正在抓取: 浪漫芭莎諾瓦 爵士經典咖啡館(關鍵字: 咖啡 爵士)
#
# 🎵 正在抓取: 咖啡廳音樂 Relaxing Coffee Music BGM(關鍵字: 咖啡 爵士)
#
# 🎵 正在抓取: 爵士 沙發音樂咖啡廳音樂(關鍵字: 咖啡 爵士)
#
# 🎵 正在抓取: c'est la vie 香榭咖啡館(關鍵字: 咖啡 爵士)
#
# 🎵 正在抓取: 聖誕氣氛鋼琴咖啡館: 爵士藍調聖誕必備精選輯(關鍵字: 咖啡 藍調)
#
# 🎵 正在抓取: 水星 藍調 咖啡 激烈(關鍵字: 咖啡 藍調)
#
# 🎵 正在抓取: 你會來看我嗎？ Firdhaus 你會來看我嗎 我愛的花 你帶了嗎 床腳下的抽屜裡 夾著幾張禮券還沒逾期 不再光臨的咖啡廳 它一定在門口等著我 不要再讓它遭受雨淋 照顧它 好嗎 抱歉 我無法 你會來看(關鍵字: 咖啡 藍調)
#
# 🎵 正在抓取: studying ur mom(關鍵字: 咖啡 藍調)
#
# 🎵 正在抓取: 手持冰咖啡散步東京（隨時更新）(關鍵字: 咖啡 R&B)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 咖啡 R&B)
#
# 🎵 正在抓取: 放鬆的英文歌(關鍵字: 咖啡 R&B)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 咖啡 重金屬)
#
# 🎵 正在抓取: 咖啡廳(鄉村)(關鍵字: 咖啡 鄉村)
#
# 🎵 正在抓取: 早上鋼琴音樂: 早上最適合聽的輕音樂, 咖啡廳鋼琴背景音樂(關鍵字: 咖啡 鋼琴)
#
# 🎵 正在抓取: 咖啡廳音樂 Relaxing Coffee Music BGM(關鍵字: 咖啡 鋼琴)
#
# 🎵 正在抓取: 輕音樂 鋼琴曲 舒適雨夜 讀書咖啡廳(關鍵字: 咖啡 鋼琴)
#
# 🎵 正在抓取: 鋼琴閱讀咖啡廳 輕音樂華語流行 古典樂大師合輯(關鍵字: 咖啡 鋼琴)
#
# 🎵 正在抓取: 鋼琴放鬆輕聽 咖啡廳 專注 讀書音樂(關鍵字: 咖啡 鋼琴)
#
# 🎵 正在抓取: 独处时，才能成为真正的自己(關鍵字: 咖啡 吉他)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 咖啡 環境音樂)
#
# 🎵 正在抓取: Chinese Indie Music / 華語獨立音樂(關鍵字: 咖啡 獨立音樂)
#
# 🎵 正在抓取: 咖啡廳音樂(關鍵字: 咖啡 獨立音樂)
#
# 🎵 正在抓取: 陳綺貞代表作(關鍵字: 咖啡 獨立音樂)
#
# 🎵 正在抓取: 悲伤的流行歌 - 1.3加速版(關鍵字: 雨天 流行)
#
# 🎵 正在抓取: CHAOSLAB混沌实验室 | 适合在下雨天听的日本流行乐歌单|雨天散步(關鍵字: 雨天 流行)
#
# 🎵 正在抓取: 下雨天散步歌单(關鍵字: 雨天 流行)
#
# 🎵 正在抓取:  (關鍵字: 雨天 古典)
#
# 🎵 正在抓取: 下雨天了怎麼辦(關鍵字: 雨天 爵士)
#
# 🎵 正在抓取: 城市歌单｜平静时刻：在樹下小坐(關鍵字: 雨天 爵士)
#
# 🎵 正在抓取: 抖音Douyin热门歌曲2025 🤍(關鍵字: 雨天 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 雨天 R&B)
#
# 🎵 正在抓取: 呱吉音樂清單總匯(關鍵字: 雨天 R&B)
#
# 🎵 正在抓取: 雨中Indie(關鍵字: 雨天 獨立音樂)
#
# 🎵 正在抓取: 陪七八年級生長大的歌(關鍵字: 旅行 流行)
#
# 🎵 正在抓取: 角頭(關鍵字: 旅行 流行)
#
# 🎵 正在抓取: 2024 中文流行歌曲精选 - 带你旅行，感受世界之声(關鍵字: 旅行 流行)
#
# 🎵 正在抓取: 华语流行(關鍵字: 旅行 流行)
#
# 🎵 正在抓取: 🌼 流行歌曲：丁香花(關鍵字: 旅行 流行)
#
# 🎵 正在抓取: 爵士旅行到巴西 爵士咖啡廳音樂(關鍵字: 旅行 爵士)
#
# 🎵 正在抓取: 高妍【東京戀愛少女】＃東京情調歌單 (關鍵字: 旅行 藍調)
#
# 🎵 正在抓取: 😘BUS TRAVELING🚍 FEELING🎶 SONG TAMIL 😘(關鍵字: 旅行 藍調)
#
# 🎵 正在抓取: 投影夜晚公路旅行(關鍵字: 旅行 靈魂)
#
# 🎵 正在抓取: 慵懶靈魂 #On the Vacation(關鍵字: 旅行 靈魂)
#
# 🎵 正在抓取: 05 Lo-fi Here(關鍵字: 夜晚 流行)
#
# 🎵 正在抓取: 夜晚輕聽的吉他鋼琴經典流行(關鍵字: 夜晚 流行)
#
# 🎵 正在抓取: 夜晚特選爵士流行樂(關鍵字: 夜晚 流行)
#
# 🎵 正在抓取: 孤單夜貓族(關鍵字: 夜晚 流行)
#
# 🎵 正在抓取: 夜晚听歌(關鍵字: 夜晚 流行)
#
# 🎵 正在抓取: 英倫搖滾 by SR(關鍵字: 夜晚 搖滾)
#
# 🎵 正在抓取: 孤單夜貓族(關鍵字: 夜晚 搖滾)
#
# 🎵 正在抓取: #7 Sleepy Strings｜Music for better sleep(關鍵字: 夜晚 古典)
#
# 🎵 正在抓取: #8 Jazzy Night｜Music for better sleep(關鍵字: 夜晚 爵士)
#
# 🎵 正在抓取: 夜晚特選爵士流行樂(關鍵字: 夜晚 爵士)
#
# 🎵 正在抓取: 夜晚爵士(關鍵字: 夜晚 爵士)
#
# 🎵 正在抓取: 爵士之夜(關鍵字: 夜晚 爵士)
#
# 🎵 正在抓取: 爵士-慢板-夜晚（公開）(關鍵字: 夜晚 爵士)
#
# 🎵 正在抓取: 80後貨車佬... 最愛(關鍵字: 夜晚 藍調)
#
# 🎵 正在抓取: 放鬆的英文歌(關鍵字: 夜晚 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 夜晚 R&B)
#
# 🎵 正在抓取: #1 Floating Slumber ｜Music for better sleep(關鍵字: 夜晚 R&B)
#
# 🎵 正在抓取: R&B 深夜中文歌曲(關鍵字: 夜晚 R&B)
#
# 🎵 正在抓取: 05 Lo-fi Here(關鍵字: 夜晚 R&B)
#
# 🎵 正在抓取: 深夜EMO歌單😭(關鍵字: 夜晚 重金屬)
#
# 🎵 正在抓取: 重金屬 嘶吼(關鍵字: 夜晚 重金屬)
#
# 🎵 正在抓取: 深夜Emo歌单(關鍵字: 夜晚 重金屬)
#
# 🎵 正在抓取: 死亡重金屬ROCK（綜合單曲）(關鍵字: 夜晚 重金屬)
#
# 🎵 正在抓取: 開車不會睡覺歌(關鍵字: 夜晚 重金屬)
#
# 🎵 正在抓取: #1 Floating Slumber ｜Music for better sleep(關鍵字: 夜晚 靈魂)
#
# 🎵 正在抓取: 心靈安定劑(關鍵字: 夜晚 靈魂)
#
# 🎵 正在抓取: 投影夜晚公路旅行(關鍵字: 夜晚 靈魂)
#
# 🎵 正在抓取: 慵懶靈魂 #At the Morning and Night(關鍵字: 夜晚 靈魂)
#
# 🎵 正在抓取: 5/10《靈魂出竅》 vol.1  導聆歌單(關鍵字: 夜晚 靈魂)
#
# 🎵 正在抓取: 鋼琴純音 放鬆舒心輕音樂 (工作/讀書/專注/療癒) Piano Music for Relax & Focus Moment(關鍵字: 夜晚 鋼琴)
#
# 🎵 正在抓取: 睡眠音樂  放鬆夜曲純音樂 舒適深層睡眠 Sleep Music of Nocturne Lullaby for Deep Sleep(關鍵字: 夜晚 環境音樂)
# ⚠️ 讀取超時!等待5秒後重試...(offset=200)
#
# 🎵 正在抓取: 適合睡覺的英文歌 (關鍵字: 夜晚 環境音樂)
#
# 🎵 正在抓取: 綠鋼琴／綠森林／古典鋼琴／現代鋼琴／助眠樂曲(關鍵字: 夜晚 環境音樂)
#
# 🎵 正在抓取: 宮崎駿放鬆睡覺覺音樂(關鍵字: 夜晚 環境音樂)
#
# 🎵 正在抓取: 深夜EMO歌單😭(關鍵字: 夜晚 環境音樂)
#
# 🎵 正在抓取: 中文流行吉他曲 Chinese Pop Guitar BGM(關鍵字: 浪漫 流行)
#
# 🎵 正在抓取: 任然好聽歌(關鍵字: 浪漫 流行)
#
# 🎵 正在抓取: 法式的浪漫電子節拍(關鍵字: 浪漫 電子)
#
# 🎵 正在抓取: OMD Remixes(關鍵字: 浪漫 電子)
#
# 🎵 正在抓取: 旭舊咖啡廳歌單(關鍵字: 浪漫 民謠)
#
# 🎵 正在抓取: 英文經典老情歌(關鍵字: 浪漫 古典)
#
# 🎵 正在抓取: 下午茶鋼琴純音樂 古典浪漫名曲 Classical music for afternoon tea(關鍵字: 浪漫 古典)
#
# 🎵 正在抓取: 浪漫時刻－古典心意－149合法公播音樂清單(關鍵字: 浪漫 古典)
#
# 🎵 正在抓取: 浪漫古典(關鍵字: 浪漫 古典)
#
# 🎵 正在抓取: 古典與浪漫派大提琴(關鍵字: 浪漫 古典)
#
# 🎵 正在抓取: 浪漫芭莎諾瓦 爵士經典咖啡館(關鍵字: 浪漫 爵士)
#
# 🎵 正在抓取: 浪漫爵士樂(關鍵字: 浪漫 爵士)
#
# 🎵 正在抓取: 浪漫爵士(關鍵字: 浪漫 爵士)
#
# 🎵 正在抓取: 爵士浪漫音樂(關鍵字: 浪漫 爵士)
#
# 🎵 正在抓取: 浪漫輕鬆爵士(關鍵字: 浪漫 爵士)
#
# 🎵 正在抓取: 《淚之女王》韓劇原聲帶(關鍵字: 浪漫 藍調)
#
# 🎵 正在抓取: 🇰🇷 歡迎來到王之國 OST(關鍵字: 浪漫 藍調)
#
# 🎵 正在抓取: 超級懷念西洋情歌(關鍵字: 浪漫 藍調)
#
# 🎵 正在抓取: This Is YOASOBI(關鍵字: 浪漫 藍調)
#
# 🎵 正在抓取: 《Run On 奔向愛情》韓劇原聲帶(關鍵字: 浪漫 藍調)
#
# 🎵 正在抓取: ✨浪漫主义与星辰海波(關鍵字: 浪漫 舞曲)
#
# 🎵 正在抓取: 西洋鄉村情歌(關鍵字: 浪漫 鄉村)
#
# 🎵 正在抓取: Kenny Rogers 肯尼羅傑斯 沙啞渾厚的嗓音，演唱鄉村歌曲入木三分(關鍵字: 浪漫 鄉村)
#
# 🎵 正在抓取: 浪漫·靈魂(關鍵字: 浪漫 靈魂)
#
# 🎵 正在抓取: 記憶中那些浪漫的歌(關鍵字: 浪漫 靈魂)
#
# 🎵 正在抓取: 獨立音樂｜抒情 浪漫 搖滾(關鍵字: 浪漫 獨立音樂)
#
# 🎵 正在抓取: 英語歌唱比賽媽媽樂幹(關鍵字: 回憶 搖滾)
#
# 🎵 正在抓取: 伍佰 & China Blue ｜Legacy TERA搖滾音樂會歌單(關鍵字: 回憶 搖滾)
#
# 🎵 正在抓取: Leaf And Stream-60‘-80‘回顧20210611(關鍵字: 回憶 搖滾)
#
# 🎵 正在抓取: 青春回憶嘻哈夜店(關鍵字: 回憶 嘻哈)
#
# 🎵 正在抓取: 「失序場」不藏私音樂清單(關鍵字: 回憶 嘻哈)
#
# 🎵 正在抓取: Leaf And Stream-60‘-80‘回顧20210611(關鍵字: 回憶 電子)
#
# 🎵 正在抓取: Leaf And Stream-60‘-80‘回顧20210611(關鍵字: 回憶 古典)
#
# 🎵 正在抓取: 爵士。早午餐。咖啡(關鍵字: 回憶 爵士)
#
# 🎵 正在抓取: 爵樂女伶的慢板(關鍵字: 回憶 爵士)
#
# 🎵 正在抓取: Leaf And Stream-60‘-80‘回顧20210611(關鍵字: 回憶 爵士)
#
# 🎵 正在抓取: 90's出生的台灣人聽什麼 Mandarin  songs for the 90’s born Taiwanese (關鍵字: 回憶 藍調)
#
# 🎵 正在抓取: 致那些在暖男時代比較吃虧的暖女們(關鍵字: 回憶 藍調)
#
# 🎵 正在抓取: 80年代華語金曲 Back To The 80’s 和你一起復刻回憶(關鍵字: 回憶 藍調)
#
# 🎵 正在抓取: 電視兒童的回憶像飄著的藍襯衫(關鍵字: 回憶 藍調)
#
# 🎵 正在抓取: April 2025: 愛是快樂的事情。(關鍵字: 回憶 藍調)
#
# 🎵 正在抓取: 開車絕對唱到醒 (關鍵字: 回憶 R&B)
#
# 🎵 正在抓取: 粤语流行音樂金榜(關鍵字: 回憶 重金屬)
#
# 🎵 正在抓取: 致那些在暖男時代比較吃虧的暖女們(關鍵字: 回憶 靈魂)
#
# 🎵 正在抓取: 深夜﹒回憶(關鍵字: 回憶 靈魂)
#
# 🎵 正在抓取: 「失序場」不藏私音樂清單(關鍵字: 回憶 獨立音樂)
#
# 🎵 正在抓取: 日本動畫電影戲劇游戲流行鋼琴曲/ Japanese Anime films Games Pop Piano BGM(關鍵字: 悠閒 流行)
#
# 🎵 正在抓取: 渡假放鬆輕爵士 Jazz & Bossa Vacation Music(關鍵字: 悠閒 爵士)
#
# 🎵 正在抓取: 放鬆木吉他  Relaxing Acoustic Guitar Music(關鍵字: 悠閒 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 悠閒 R&B)
#
# 🎵 正在抓取: 輕鬆不插電(關鍵字: 悠閒 舞曲)
#
# 🎵 正在抓取: 靈魂悠閒mellow迷幻復古慵懶(關鍵字: 悠閒 靈魂)
#
# 🎵 正在抓取: 台灣流行歌曲鋼琴音樂 Taiwan Pop Piano Instrumental(關鍵字: 孤獨 流行)
#
# 🎵 正在抓取: 最好聽閩南台語歌曲 Best Minnan Hokkien and Taiwanese Songs(關鍵字: 孤獨 流行)
#
# 🎵 正在抓取: 治愈中文流行鋼琴音樂 Soothing Piano Cover Mandarin Pop Songs 🎹(關鍵字: 孤獨 流行)
#
# 🎵 正在抓取: 烟嗓伤情歌(關鍵字: 孤獨 流行)
#
# 🎵 正在抓取: 日本動畫電影戲劇游戲流行鋼琴曲/ Japanese Anime films Games Pop Piano BGM(關鍵字: 孤獨 流行)
#
# 🎵 正在抓取: 孤獨搖滾｜ぼっち・ざ・ろっく！｜Bocchi the Rock !(關鍵字: 孤獨 搖滾)
#
# 🎵 正在抓取: 孤獨搖滾全曲目(關鍵字: 孤獨 搖滾)
#
# 🎵 正在抓取: 孤獨搖滾！ OP ED OST(關鍵字: 孤獨 搖滾)
#
# 🎵 正在抓取: 超好聽日文歌 日本動漫歌(關鍵字: 孤獨 搖滾)
#
# 🎵 正在抓取: 【總集篇歌曲 新增！】孤獨搖滾！(關鍵字: 孤獨 搖滾)
#
# 🎵 正在抓取: Hip Hop V - 嘻哈寶典 Give Me 5(關鍵字: 孤獨 嘻哈)
#
# 🎵 正在抓取: NCT 127 HIP-HOP TRACKS ♪(關鍵字: 孤獨 嘻哈)
#
# 🎵 正在抓取: 「失序場」不藏私音樂清單(關鍵字: 孤獨 嘻哈)
#
# 🎵 正在抓取: 最受歡迎香港中文歌曲 Top Hong Kong Chinese Songs(關鍵字: 孤獨 電子)
#
# 🎵 正在抓取: 最好聽閩南台語歌曲 Best Minnan Hokkien and Taiwanese Songs(關鍵字: 孤獨 民謠)
#
# 🎵 正在抓取: 北歐櫥窗 × 林貓王：好自在的居家音樂(關鍵字: 孤獨 民謠)
#
# 🎵 正在抓取: 大半夜趕報告趕作品很煩捏(關鍵字: 孤獨 民謠)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 孤獨 民謠)
#
# 🎵 正在抓取: 【中國風】超好聽的中國古典音樂 (古箏、琵琶、竹笛、二胡) 中國風純音樂的獨特韻味 - 古箏音樂 放鬆心情 安靜音樂 长笛音乐结合古筝 - Traditional Chinese Music(關鍵字: 孤獨 古典)
#
# 🎵 正在抓取: 【中國風】超好聽的中國古典音樂 (古箏、琵琶、竹笛、二胡) 中國風純音樂的獨特韻味 - 古箏音樂 放鬆心情 安靜音樂 长笛音乐结合古筝 - Traditional Chinese Music(關鍵字: 孤獨 古典)
#
# 🎵 正在抓取: 琵琶獨奏(關鍵字: 孤獨 古典)
#
# 🎵 正在抓取: DECCA古典．留聲傳奇(關鍵字: 孤獨 古典)
#
# 🎵 正在抓取: 久石讓難忘的音樂 2025  Music by Joe Hisaishi(關鍵字: 孤獨 古典)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 孤獨 爵士)
#
# 🎵 正在抓取: 中文爵士流行歌曲 2024 Chinese Pop Jazz(關鍵字: 孤獨 爵士)
#
# 🎵 正在抓取: Retro Chinese City Pop: 復古風中文城市流行 中文citypop(關鍵字: 孤獨 爵士)
#
# 🎵 正在抓取: 頹頹精選(關鍵字: 孤獨 爵士)
#
# 🎵 正在抓取: 最受歡迎香港中文歌曲 Top Hong Kong Chinese Songs(關鍵字: 孤獨 爵士)
#
# 🎵 正在抓取: 蔡健雅 _情歌精選(關鍵字: 孤獨 藍調)
#
# 🎵 正在抓取: 超好聽日文歌 日本動漫歌(關鍵字: 孤獨 藍調)
#
# 🎵 正在抓取: 都是我喜歡的歌而且跟我的人生一樣亂成一團(關鍵字: 孤獨 藍調)
#
# 🎵 正在抓取: [KKBOX]ㄧ個人的孤單，靜靜地聽歌就沒事了。 / 2024-12-27(關鍵字: 孤獨 藍調)
#
# 🎵 正在抓取: 跟著🅐🅛🅘好好玩《創意鍵盤》圈圈Ｉ(關鍵字: 孤獨 藍調)
#
# 🎵 正在抓取: 手持冰咖啡散步東京（隨時更新）(關鍵字: 孤獨 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 孤獨 R&B)
#
# 🎵 正在抓取: 台灣流行歌曲鋼琴音樂 Taiwan Pop Piano Instrumental(關鍵字: 孤獨 R&B)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 孤獨 靈魂)
#
# 🎵 正在抓取: 時代少年團     TF3代   T.O.P登陸少年組合（all ）（我把ㄧ些無法播放的音檔刪了所以現在變成只有67小時多而已）(關鍵字: 孤獨 靈魂)
#
# 🎵 正在抓取: Dark Melody - Horror  Artistic inspiration 萬物沉寂 (Painting Use)  Creepy Music(關鍵字: 孤獨 靈魂)
#
# 🎵 正在抓取: ㄧ個人的孤單，靜靜地聽歌就沒事了。 #獨處 #安靜(關鍵字: 孤獨 鋼琴)
#
# 🎵 正在抓取: [KKBOX]ㄧ個人的孤單，靜靜地聽歌就沒事了。 / 2024-12-27(關鍵字: 孤獨 鋼琴)
#
# 🎵 正在抓取: 20221219 鋼琴巨星趙成珍獨奏會(關鍵字: 孤獨 鋼琴)
#
# 🎵 正在抓取: Taiwanese Bands(關鍵字: 孤獨 吉他)
#
# 🎵 正在抓取: 獨立新浪潮(關鍵字: 孤獨 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 孤獨 獨立音樂)
#
# 🎵 正在抓取: 台語獨立音樂(關鍵字: 孤獨 獨立音樂)
# ⚠️ 讀取超時!等待5秒後重試...(offset=100)
#
# 🎵 正在抓取: 中国民谣(關鍵字: 自由 流行)
#
# 🎵 正在抓取: Aiuanyu 愛灣語流行電臺(關鍵字: 自由 流行)
#
# 🎵 正在抓取: 自由(關鍵字: 自由 流行)
#
# 🎵 正在抓取: 邦ロック好きなら知っておくべき注目バンド(關鍵字: 自由 流行)
#
# 🎵 正在抓取: 準備中に聞きたい(關鍵字: 自由 流行)
#
# 🎵 正在抓取: 古典音律｜｜汉尼拔的深夜食堂(關鍵字: 自由 古典)
#
# 🎵 正在抓取: ✨浪漫主义与星辰海波(關鍵字: 自由 古典)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 自由 爵士)
#
# 🎵 正在抓取: 器乐爵士|演奏的自由(關鍵字: 自由 爵士)
#
# 🎵 正在抓取: 自由爵士(關鍵字: 自由 爵士)
#
# 🎵 正在抓取: 村上春樹の爵士情緣(關鍵字: 自由 爵士)
#
# 🎵 正在抓取: 茄子蛋 EggPlantEgg｜必聽精選 TOP HITS(關鍵字: 自由 藍調)
#
# 🎵 正在抓取: 進撃の巨人/進擊的巨人 OP&ED全曲(關鍵字: 自由 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 自由 R&B)
#
# 🎵 正在抓取: 🎵自由舞曲🎵(關鍵字: 自由 舞曲)
#
# 🎵 正在抓取: ✨浪漫主义与星辰海波(關鍵字: 自由 舞曲)
#
# 🎵 正在抓取: 鄉村呢喃 自由和溫柔(關鍵字: 自由 鄉村)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 自由 靈魂)
#
# 🎵 正在抓取: 自由靈魂(關鍵字: 自由 靈魂)
#
# 🎵 正在抓取: 《哲仁王后》韓劇原聲帶(關鍵字: 自由 靈魂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 自由 獨立音樂)
#
# 🎵 正在抓取: 獨立樂團 - 2024(關鍵字: 自由 獨立音樂)
#
# 🎵 正在抓取: 獨立新浪潮(關鍵字: 自由 獨立音樂)
#
# 🎵 正在抓取: 台灣獨立樂團 Taiwan Indie(關鍵字: 自由 獨立音樂)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 釋放 流行)
#
# 🎵 正在抓取: 治愈中英文流行鋼琴音樂 Soothing Piano Cover Mandarin & English Pop Songs 🎹(關鍵字: 釋放 流行)
#
# 🎵 正在抓取: 任然好聽歌(關鍵字: 釋放 流行)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 釋放 搖滾)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 釋放 民謠)
#
# 🎵 正在抓取: 馬友友 Yo-Yo Ma 古典主打星(關鍵字: 釋放 古典)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 釋放 爵士)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 釋放 爵士)
#
# 🎵 正在抓取: 馬友友 Yo-Yo Ma 古典主打星(關鍵字: 釋放 爵士)
#
# 🎵 正在抓取: 我們心裡的梁靜茹：陪我們為愛傷痛，愛過的情歌。(關鍵字: 釋放 藍調)
#
# 🎵 正在抓取: iX1-TWC 夢幻女聲(關鍵字: 釋放 藍調)
#
# 🎵 正在抓取: 最好聽翻唱歌曲 Best Chinese Cover Songs(關鍵字: 釋放 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 釋放 R&B)
#
# 🎵 正在抓取: 治愈中英文流行鋼琴音樂 Soothing Piano Cover Mandarin & English Pop Songs 🎹(關鍵字: 釋放 R&B)
#
# 🎵 正在抓取: 爵士小酒館(關鍵字: 釋放 靈魂)
#
# 🎵 正在抓取: 心靈安定劑(關鍵字: 釋放 靈魂)
#
# 🎵 正在抓取: 靈魂釋放(關鍵字: 釋放 靈魂)
#
# 🎵 正在抓取: 滾石40撞樂隊 翻唱與原唱 完整合輯(關鍵字: 釋放 吉他)
#
# 🎵 正在抓取: 七年級生的華語回憶電台(關鍵字: 幸福 流行)
#
# 🎵 正在抓取: 中国民谣(關鍵字: 幸福 流行)
#
# 🎵 正在抓取: 悲伤情歌 Top Hit Mandarin Songs 2024 - 最新流行好听伤心歌曲(關鍵字: 幸福 流行)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 幸福 嘻哈)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 幸福 電子)
#
# 🎵 正在抓取: 為自己的幸福加油 輕鬆古典(關鍵字: 幸福 古典)
#
# 🎵 正在抓取: 周興哲（如果雨之後-愛在身邊-愛 教會我們的事-學著愛)+Eric編曲(關鍵字: 幸福 藍調)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 幸福 藍調)
#
# 🎵 正在抓取: 这或许就是人生(關鍵字: 幸福 藍調)
#
# 🎵 正在抓取: 梁文音｜情歌精選(關鍵字: 幸福 R&B)
#
# 🎵 正在抓取: 英文抒情R&B(關鍵字: 幸福 R&B)
#
# 🎵 正在抓取: Hip Hop Luv(嘻哈寶典談戀愛)(關鍵字: 幸福 靈魂)
#
# 🎵 正在抓取: 獨立樂團不用滑(關鍵字: 幸福 獨立音樂)
#
# 🎵 正在抓取: 陪七八年級生長大的歌(關鍵字: 成長 流行)
#
# 🎵 正在抓取: 七年級生台灣流行 Mando Pop(關鍵字: 成長 流行)
#
# 🎵 正在抓取: 陪著90後成長的廣東流行曲(關鍵字: 成長 流行)
#
# 🎵 正在抓取: 陪著90後成長的廣東流行曲(關鍵字: 成長 流行)
#
# 🎵 正在抓取: 陪著90後成長的廣東流行曲:12/1/2023(關鍵字: 成長 流行)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 成長 民謠)
#
# 🎵 正在抓取: 寶寶潛能開發音樂 胎教古典音樂  Baby Brain Development Music ＆  Pregnancy Music(關鍵字: 成長 古典)
#
# 🎵 正在抓取: 愛唱歌親子演唱會《米卡勇闖魔法夢奇地》(關鍵字: 成長 藍調)
#
# 🎵 正在抓取: 《 俗女養成記2 》俗女2  完整台劇原聲帶 OST (關鍵字: 成長 藍調)
#
# 🎵 正在抓取: 六年級愛情歌(關鍵字: 成長 藍調)
#
# 🎵 正在抓取: 🇨🇳 神隱 OST(關鍵字: 成長 藍調)
#
# 🎵 正在抓取: 微涼之夏「商業電台65週年廣播劇」Soundtrack(關鍵字: 成長 藍調)
#
# 🎵 正在抓取: 愛唱歌親子演唱會《米卡勇闖魔法夢奇地》(關鍵字: 成長 R&B)
#
# 🎵 正在抓取: 寶寶潛能開發音樂 胎教古典音樂  Baby Brain Development Music ＆  Pregnancy Music(關鍵字: 成長 環境音樂)
#
# 🎵 正在抓取: 原創歌曲 Original Song | Jesse T(關鍵字: 成長 獨立音樂)
#
# ✅ 已完成,總共抓取 117159 首歌,結果已儲存:Taiwan_Playlist_Songs.csv

# %% [markdown]
# ## 6️⃣ 轉檔成文字檔

# %%
import pandas as pd

# 讀取已經抓好的 CSV
df = pd.read_csv("Taiwan_Playlist_Songs.csv", encoding='utf-8-sig')

# 轉成自訂格式的純文字
with open("Taiwan_Playlist_Songs.txt", "w", encoding='utf-8-sig') as f:
    for _, row in df.iterrows():
        line = f"播放清單: {row['播放清單名稱']} | 關鍵字: {row['搜尋關鍵字']} | 歌曲: {row['歌曲名稱']} | 藝人: {row['藝人']} | 專輯: {row['專輯']} | 發行日: {row['發行日']}\n"
        f.write(line)

print("✅ 已轉存成自訂格式 TXT:Taiwan_Playlist_Songs.txt")
# Out:
# ✅ 已轉存成自訂格式 TXT:Taiwan_Playlist_Songs.txt
