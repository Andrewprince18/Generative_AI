# %% [markdown]
# # 風格定向圖像生成：創作與挑選

# %% [markdown]
# ## 🎨 使用繪圖風格
# <hr>
# 在此設定整體的圖片風格為以下：
#
# - 手繪插畫風（Hand-drawn illustration）
#
# - 復古童書風格（Vintage children's book style）
#
# - 柔和水彩質感（Soft watercolor textures）
#
# - 細緻線條（Fine sketch lines）
#
# - 粉彩色調（Pastel colors）
#
# - 溫暖氛圍（Gentle and warm atmosphere）
#
# - 簡單的背景（Simple background）
#
# - 紙張紋理質感（Drawn on textured paper）

# %% [markdown]
# ## 👤 主要角色特徵
# <hr>
# 在此設定圖片中如果有主要角色的話其風格為以下：
#
# - 自然比例（非Q版、無大頭小身）
#
# - 寫實柔和的五官（Realistic and soft facial features）
#
# - 表情細膩、不誇張（Subtle expression）
#
# - 避免卡通式五官（Not cartoonish or exaggerated）

# %% [markdown]
# # 🐱 Prompt 1
# <hr>
# 透過以上我選定的特性，請 ChatGPT 生成 prompt 接著放入 bing create 中，
#
# 在此想繪製一幅手繪風格的插畫，畫面是一隻花貓在彈吉他。
#
# ### 輸入 prompt:
#
# " A hand-drawn illustration of a calico cat playing guitar, vintage children's book style, soft watercolor textures, fine sketch lines, pastel colors, gentle and warm atmosphere, detailed but simple background, with realistic and soft facial features (not cartoonish or exaggerated), subtle expression, drawn on textured paper "
#
# ### 輸出:
# ![06f937a5-a522-4a6a-8074-849eb6200852.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 🐸 Prompt 2
# <hr>
# 修改了 ChatGPT 生成的 prompt 再放入 bing create 中，
#
# 根據相同的風格設定，我想繪製一幅手繪風格的插畫，畫面是一隻青蛙拿著鑰匙。
#
# ### 輸入 prompt:
#
# " A hand-drawn illustration of a dark green frog holding a key, vintage children's book style, soft watercolor textures, fine sketch lines, pastel colors, gentle and warm atmosphere, detailed but simple background, with realistic and soft facial features (not cartoonish or exaggerated), subtle expression, drawn on textured paper
# "
#
# ### 輸出:
# ![8de9a3c5-6bec-422f-9916-a9a8be8d57fd.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 🤖 Prompt 3
# <hr>
# 修改了 ChatGPT 生成的 prompt 再放入 bing create 中，
#
# 根據相同的風格設定，我想繪製一幅手繪風格的插畫，畫面是兩隻鋼彈正在戰鬥。
#
# ### 輸入 prompt:
#
# " A hand-drawn illustration of two Gundam robots in a gentle battle scene, vintage children's book style, soft watercolor textures, fine sketch lines, pastel colors, gentle and warm atmosphere, detailed but simple background, with soft mechanical details (not overly sharp or aggressive), subtle action poses, drawn on textured paper "
#
# ### 輸出:
# ![6b7fcfef-e6c8-45d8-bc5e-3aea5f5949bf.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 🍪 Prompt 4
# <hr>
# 修改了 ChatGPT 生成的 prompt 再放入 bing create 中，
#
# 根據相同的風格設定，繪製一幅手繪風格的插畫，畫面是一個黑色長髮的女生在吃餅乾。
#
# ### 輸入 prompt:
#
# " A hand-drawn illustration of a long-haired girl with dark hair, eyes open, gently biting into a cookie. Her eyes are softly drawn, not overly large or cartoonish. The illustration is in a vintage children's book style, with soft watercolor textures, fine sketch lines, pastel colors, a gentle and warm atmosphere, and a detailed but simple background. Her facial features are realistic and subtle, with a calm expression, all drawn on textured paper "
#
# ### 輸出:
# ![836982b4-02e8-40a0-8b1e-2452f983443e.jpeg](data:image/jpeg;base64,...)
